# %% [markdown]
# <a href="https://colab.research.google.com/github/vivekp12/dst-group-project-2/blob/main/VivekP/ForConsistency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# >[Introduction](#scrollTo=rKCfp20CeRoj)
#
# ><br>[Requirements](#scrollTo=4tjtYwXiTGbg)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[1.1 Data Augmentation](#scrollTo=Db4dvLsLU0UY)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[1.2 Train and Test Splitting](#scrollTo=ZP8zGYwkUv6z)
#
# ><br>[Model Training (Base Model)](#scrollTo=mj1aL4LyWNlZ)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[2.1 Building and training the Model](#scrollTo=hrWYKmiEVr4S)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[2.2 Train and Test Accuracy](#scrollTo=dQ9sN6o4fVEc)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[2.3 Plotting Training History](#scrollTo=Uu83BmTBftLA)
#
# ><br>[Paramter Tuning](#scrollTo=XmZNI5WWXyW5)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[3.1 Regularisation](#scrollTo=mdow1495uRyJ)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[3.1.1 Building and Training the Model](#scrollTo=EvOT0wmAvAjO)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[3.1.2 Train and Test Accuracy](#scrollTo=0T3yz2nHvQhY)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[3.1.3 Plotting Training History](#scrollTo=AuvTYjPtvcO3)
#
# ><br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[3.2 Early Stopping](#scrollTo=mbpE8SoT077u)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[3.2.1 Building and Training the Model](#scrollTo=Eh0amf4OYEoV)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[3.2.2 Train and Test Accuracy](#scrollTo=UbxaFmSlYWMs)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[3.2.3 Plotting Training History](#scrollTo=n6OdaKHTZUnU)
#
# ><br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[3.3 Learning Rate](#scrollTo=Kg2qgirW15y2)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[3.3.1 Building and Training the Model](#scrollTo=kmXSLbNdZtFe)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[3.3.2 Train and Test Accuracy](#scrollTo=xi5BDDbIZ7SS)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[3.3.3 Plotting Training History](#scrollTo=HOI7dj0TaKuX)
#
# ><br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[3.4 Xavier Initialisation](#scrollTo=qBTD-GeqP7WE)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[3.4.1 Building and Training the Model](#scrollTo=q_R_yJjeSQnq)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[3.4.2 Train and Test Accuracy](#scrollTo=NP3zt-sHSetx)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[3.4.3 Plotting Training History](#scrollTo=RXaz3ADKSjoN)
#
# ><br>[Evaluating on Test Data](#scrollTo=ztNRGf3QSsSl)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[4.1 Base Model](#scrollTo=VNn1p1J946tB)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[4.2 Model with Regularisation](#scrollTo=EWrhvpbG5pKE)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[4.3 Model with Early Stopping](#scrollTo=khKqgst35w_s)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[4.3 Model with Reduced Learning Rate](#scrollTo=czw6xcZBCbcg)
#
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[4.4 Model with Xavier Initialisation](#scrollTo=uRcHwNoM52YA)
#
# ><br>[Conclusion](#scrollTo=0lU9iP84AF3V)

# %% [markdown]
# # Introduction
# The following set of code aims to investigate model creation and performance using neural networks for the [Brain Tumour MRI](https://www.kaggle.com/datasets/masoudnickparvar/brain-tumor-mri-dataset/data) dataset consisting of images divided into 4 main categories, glioma, meningioma, no tumour and pituatary, by considering the tanh activation function for a CNN (Convolution Neural Netowrk) model (explained [here](https://github.com/vivekp12/dst-group-project-2/blob/main/MarkM/ConvolutionLayers.ipynb)). We analyze how hyperparamater tuning (in this case learning rate, regularisation, weight initialisation and early stopping) affect model perforamnce by graphical represenations to show training and validation scores and losses. Keeping in mind that on downloading the folder of all the images, it is divided firstly into training and testing folders, one random image from the testing folder is chosen to test the model and evaluate its prediction power (for each hyperparameter tuning, this is done to analyze any relevant changes).
# <br>
# While hyperparameter tuning is an important part of this analysis, majority of the importance is given to create a distinction between 3 different activation functions and their effect on the prediction power of the respective models created for the Brain Tumour MRI dataset ([Swish](https://github.com/vivekp12/dst-group-project-2/blob/main/MarkM/Swish_research.ipynb) and [ReLU](https://github.com/vivekp12/dst-group-project-2/blob/main/VivekP/04-ReLUInvestigation.ipynb) being the other 2). The factors in common betweent the 3 projects created is the preprocessing of the data, checking for duplication and the optimizer used, which in this case is the Adam optimizer. The reason for selecting the Adam optimizer is for relatively faster convergence, the robustness allowing it to work well on a wide range of architectures and datasets and bias correction. Adam maintains adaptive learning rate for each parameters by considering two moving averages, the first moment estimate ($m_t$) and the second moment estimate ($v_t$), the former responsible for capturing the mean enabling necessary stabilizing updates, while the latter focuses on the varaince, thereby scaling parametrs. Both consist of inital bias correctors $\hat{m_t}$ and $\hat{v_t}$, which ensure stable estimates during hte initial steps of the training.

# %% [markdown]
# <br>

# %% [markdown]
# #1. Requirements
# Data augmentation which includes creating a cleaned folder of the training and testing images to have some sort of uniformity with respect to grey scaling of images or fixing dead pixels is performed. It is also observed that duplicates (if any) are checked and removed. This is an integral part for creating neural networks since data can be badly presented and unready for model creation which causes unnatural complexities during compiling, such as underperformance due to noise or even false prediction due to over or under fitting.

# %% [markdown]
# # 1.1 Data Augmentation

# %%
from pathlib import Path  # Import pathlib to work with paths
import kagglehub
import os  # Import os module for file operations
import hashlib
import numpy as np
from tqdm import tqdm
import cv2
import os
import imutils

# Download latest version
path = kagglehub.dataset_download("masoudnickparvar/brain-tumor-mri-dataset")

print("Path to dataset files:", path)

# Convert path to a Path object
path = Path(path)

PROJECT_DIR = path
LABELS = ['pituitary', 'notumor', 'meningioma', 'glioma']
def crop_img(img):
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    gray = cv2.GaussianBlur(gray, (3, 3), 0)
    thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
    thresh = cv2.erode(thresh, None, iterations=2)
    thresh = cv2.dilate(thresh, None, iterations=2)
    cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    c = max(cnts, key=cv2.contourArea)
    extLeft = tuple(c[c[:, :, 0].argmin()][0])
    extRight = tuple(c[c[:, :, 0].argmax()][0])
    extTop = tuple(c[c[:, :, 1].argmin()][0])
    extBot = tuple(c[c[:, :, 1].argmax()][0])
    ADD_PIXELS = 0
    new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()
    return new_img


# Convert 'path' to Path object (already done above)
train_dir = path / "Training"
test_dir = path / "Testing"

if __name__ == "__main__":
    training = train_dir
    testing = test_dir

    training_dir = os.listdir(training)
    testing_dir = os.listdir(testing)

    IMG_SIZE = 256

    for dir in training_dir:
        save_path = Path('cleaned/Training') / dir  # Using pathlib's '/' operator
        path = training / dir  # Using pathlib's '/' operator
        image_dir = os.listdir(path)

        for img in image_dir:
            image = cv2.imread(str(path / img))  # Convert Path to string for OpenCV
            new_img = crop_img(image)
            new_img = cv2.resize(new_img, (IMG_SIZE, IMG_SIZE))

            if not save_path.exists():
                save_path.mkdir(parents=True)

            cv2.imwrite(str(save_path / img), new_img)  # Convert Path to string for OpenCV

    for dir in testing_dir:
        save_path = Path('cleaned/Testing') / dir
        path = testing / dir
        image_dir = os.listdir(path)

        for img in image_dir:
            image = cv2.imread(str(path / img))
            new_img = crop_img(image)
            new_img = cv2.resize(new_img, (IMG_SIZE, IMG_SIZE))

            if not save_path.exists():
                save_path.mkdir(parents=True)

            cv2.imwrite(str(save_path / img), new_img)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/masoudnickparvar/brain-tumor-mri-dataset?dataset_version_number=1...
# 100%|██████████| 149M/149M [00:07<00:00, 19.8MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1

# %%
def compute_hash(file):
    hasher = hashlib.md5()
    with open(file, 'rb') as f:
        buf = f.read()
        hasher.update(buf)
    return hasher.hexdigest()


def list_files(hash_dict):
    for data_type in ['Training', 'Testing']:
        for label in LABELS:
            folder_path = os.path.join(PROJECT_DIR, 'data', 'raw', data_type, label)
            for root, dirs, files in os.walk(folder_path):
                for file in files:
                    if file.endswith(".jpg"):
                        file_path = os.path.join(root, file)
                        file_hash = compute_hash(file_path)
                        if file_hash in hash_dict:
                            hash_dict[file_hash].append(file_path)
                        else:
                            hash_dict[file_hash] = [file_path]


def remove_duplicates(hash_dict):
    duplicate_count = 0
    for hash_value, file_paths in hash_dict.items():
        if len(file_paths) > 1:
            for file_path in file_paths[1:]:
                print(f"Removing duplicate (hash : {hash_value}) : {file_path}")
                os.remove(file_path)
                duplicate_count += 1
    print(f"Number of duplicates : {duplicate_count}")


if __name__ == '__main__':
    hash_dict = {}
    list_files(hash_dict)
    remove_duplicates(hash_dict)
# Out:
# Number of duplicates : 0

# %% [markdown]
# <br>

# %% [markdown]
# # 1.2 Train and Test Splitting
#
#
# In this section we aim to use the function __ImageDataGenerator()__ as a means to preprocess the images in both the training and testing folders of the Brain MRI folder. This is done to create changes to images that promotes randomness and allows the model to generalise better on the available data and also on unseen data while testing.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
from pathlib import Path
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adamax
from sklearn.metrics import classification_report, confusion_matrix

# Define directories for training and testing images
train_dir = Path('cleaned/Training')
test_dir = Path('cleaned/Testing')

# Number of classes
LABELS = ['pituitary', 'notumor', 'meningioma', 'glioma']

# Image size and batch size
IMG_SIZE = 64  # Resize images to 64x64
BATCH_SIZE = 32

# Setup ImageDataGenerators for loading and preprocessing the images
train_datagen = ImageDataGenerator(
    rescale=1.0/255.0,  # Normalize pixel values to [0, 1]
    rotation_range=20,  # Random rotation
    width_shift_range=0.1,  # Horizontal shift
    height_shift_range=0.1,  # Vertical shift
    shear_range=0.2,  # Shear transformation
    zoom_range=0.2,  # Zoom in and out
    horizontal_flip=True,  # Flip horizontally
    fill_mode='nearest',  # Fill any missing pixels using the nearest pixel
    brightness_range=(0.5, 1.5),  # Randomly adjust brightness between 0.5 and 1.5 times the original
    channel_shift_range=20.0  # Randomly shift RGB channels (intensity)
)

test_datagen = ImageDataGenerator(rescale=1.0/255.0)  # Only rescale for test data

# Load images from directories using ImageDataGenerator
print('Training Data: ')

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),  # Resize images to 64x64
    batch_size=BATCH_SIZE,
    class_mode='categorical', # For multi-class classification
    shuffle=True
)


print('Testing Data: ')
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),  # Resize images to 64x64
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False  # Do not shuffle for test data
)
# Out:
# Training Data:
# Found 5712 images belonging to 4 classes.
# Testing Data:
# Found 1311 images belonging to 4 classes.

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# # 2. Model Training (Base Model)

# %% [markdown]
# # 2.1 Building and training the Model
# We use __Convlolution Neural Networks(CNN)__ with the __Tanh activation function__ on multiple input layers and __softmax__ function on the output layer for 4 classes. Model compiling takes place with the __Adam__ optimiser using the loss function as __categorical_crossentropy__ for a multi-class classificaton model consisting of mutliple output layers.
#
# <br>
#
# __Why the choice of__ __tanh__ __activation function ?__
# While there is no "best" activation function since each of them are used based on the data and the problem at hand, the choice of this activation function is merely for experimental purposes only. As a group each of us have chosen one based on our interests and consequenly an apt amount of research is performed.
# The tanh acitvation function used in neural networks given by:
# <div align="center"> $$ f(x) = \frac{e^x - e^{-x}}{e^x + e^{-x}} $$
# <br>
# <div align="left">
# is commonly used in Deep Neural Network (DNN) situtations to represent hidden layers. Also known as Hyperbolic Tangent Activation Function, it transforms input data into the values between -1 and 1 and accomodates the non-linearity between input and output data to learn more complex relationships. It is symmetric around the origin which in leighman's term means assigning negative values to negative data and positive to positive ones. This also means that the gradients are balanced when the weights are updated leading to faster convergence during training, but it is still susceptible to the vanishing gradient problem (gradients approaching zero when input is very large or very small). In backpropagation, each layer computes gradients based on the layer that follows it. If one layer has a very small gradient, it "passes" that small gradient backward, causing the earlier layers to receive even smaller gradients. This effect compounds in deep networks, particularly for networks with many layers.
# <br>
# The code and output below shows the usage of the tanh function along with accuracies obtained for both validation and training.

# %%
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam

# Build an optimized CNN model
model_base = Sequential([
    Conv2D(64, kernel_size=(3, 3), activation='tanh', input_shape=(64, 64, 3)),
    MaxPooling2D((2, 2)),

    Conv2D(128, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),

    Conv2D(256, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),

    Conv2D(512, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),

    Flatten(),
    Dense(512, activation='tanh'),
    Dense(128, activation='tanh'),

    Dense(4, activation='softmax')  # Output layer for 4 classes
])

model_base.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Train the model
history_base = model_base.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=100,  # Increased epochs to get better training results
    validation_data=test_generator,
    validation_steps=test_generator.samples // BATCH_SIZE
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 25s 110ms/step - accuracy: 0.3983 - loss: 1.3771 - val_accuracy: 0.6687 - val_loss: 0.8272
# Epoch 2/100
#   1/178 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.5938 - loss: 0.9003
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5938 - loss: 0.9003 - val_accuracy: 0.8710 - val_loss: 0.6073
# Epoch 3/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 95ms/step - accuracy: 0.6454 - loss: 0.8602 - val_accuracy: 0.7453 - val_loss: 0.6652
# Epoch 4/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 161us/step - accuracy: 0.8438 - loss: 0.5895 - val_accuracy: 1.0000 - val_loss: 0.0988
# Epoch 5/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 90ms/step - accuracy: 0.7248 - loss: 0.7144 - val_accuracy: 0.7758 - val_loss: 0.5866
# Epoch 6/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 137us/step - accuracy: 0.8750 - loss: 0.3490 - val_accuracy: 1.0000 - val_loss: 0.0714
# Epoch 7/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - accuracy: 0.8059 - loss: 0.5367 - val_accuracy: 0.7937 - val_loss: 0.5511
# Epoch 8/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8750 - loss: 0.3532 - val_accuracy: 1.0000 - val_loss: 0.0613
# Epoch 9/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - accuracy: 0.8107 - loss: 0.5208 - val_accuracy: 0.8172 - val_loss: 0.4718
# Epoch 10/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8438 - loss: 0.4099 - val_accuracy: 1.0000 - val_loss: 0.0811
# Epoch 11/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 93ms/step - accuracy: 0.8132 - loss: 0.5039 - val_accuracy: 0.8367 - val_loss: 0.4412
# Epoch 12/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9062 - loss: 0.3244 - val_accuracy: 0.9677 - val_loss: 0.2016
# Epoch 13/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 91ms/step - accuracy: 0.8285 - loss: 0.4575 - val_accuracy: 0.8594 - val_loss: 0.4302
# Epoch 14/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 132us/step - accuracy: 0.8438 - loss: 0.4854 - val_accuracy: 0.8710 - val_loss: 0.2968
# Epoch 15/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 90ms/step - accuracy: 0.8499 - loss: 0.4222 - val_accuracy: 0.8656 - val_loss: 0.3853
# Epoch 16/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step - accuracy: 0.7188 - loss: 0.6669 - val_accuracy: 0.9677 - val_loss: 0.2787
# Epoch 17/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 93ms/step - accuracy: 0.8413 - loss: 0.4223 - val_accuracy: 0.8461 - val_loss: 0.4297
# Epoch 18/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - accuracy: 0.8750 - loss: 0.6218 - val_accuracy: 1.0000 - val_loss: 0.0307
# Epoch 19/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 90ms/step - accuracy: 0.8709 - loss: 0.3693 - val_accuracy: 0.8344 - val_loss: 0.4746
# Epoch 20/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - accuracy: 0.8750 - loss: 0.5300 - val_accuracy: 1.0000 - val_loss: 0.0536
# Epoch 21/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - accuracy: 0.8780 - loss: 0.3539 - val_accuracy: 0.8367 - val_loss: 0.4111
# Epoch 22/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 118us/step - accuracy: 0.8750 - loss: 0.5902 - val_accuracy: 1.0000 - val_loss: 0.0302
# Epoch 23/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 90ms/step - accuracy: 0.8634 - loss: 0.3657 - val_accuracy: 0.8648 - val_loss: 0.3696
# Epoch 24/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 96us/step - accuracy: 0.9062 - loss: 0.2180 - val_accuracy: 1.0000 - val_loss: 0.0333
# Epoch 25/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 96ms/step - accuracy: 0.8749 - loss: 0.3406 - val_accuracy: 0.8602 - val_loss: 0.3971
# Epoch 26/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s
evaluate(test_generator)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 86ms/step - accuracy: 0.9019 - loss: 0.2755
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8831 - loss: 0.2900
# Train Loss:  0.27188920974731445
# Train Accuracy:  0.899334728717804
# --------------------
# --------------------
# Test Loss:  0.25344401597976685
# Test Accuracy:  0.9054157137870789

# %% [markdown]
# <br>

# %% [markdown]
# # 2.3 Plotting Training History

# %%
plt.plot(history_base.history['accuracy'], label='Training Accuracy')
plt.plot(history_base.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(history_base.history['loss'], label='Training Loss')
plt.plot(history_base.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# <br>

# %%
model_base.save('model_base.keras')

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# # 3. Paramter Tuning

# %% [markdown]
# # 3.1 Regularisation
# Regularisation is introduced through __BatchNormalisation()__ and __Dropout=0.5__ to stabilize training and balance the trade-off between keeping enough neurons to learn meaningful patterns and enforcing regularization to prevent overfitting.

# %% [markdown]
# # 3.1.1 Building and Training the Model

# %%
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam

# Build an optimized CNN model
model_reg = Sequential([
    Conv2D(64, kernel_size=(3, 3), activation='tanh', input_shape=(64, 64, 3)),
    MaxPooling2D((2, 2)),
    BatchNormalization(),

    Conv2D(128, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),
    BatchNormalization(),

    Conv2D(256, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),
    BatchNormalization(),

    Conv2D(512, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),
    BatchNormalization(),

    Flatten(),
    Dense(512, activation='tanh'),
    Dropout(0.5),  # Adding dropout for regularization
    Dense(128, activation='tanh'),
    Dropout(0.5),  # Adding another dropout layer

    Dense(4, activation='softmax')  # Output layer for 4 classes
])

model_reg.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history_reg = model_reg.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=100,  # Increased epochs to get better training results
    validation_data=test_generator,
    validation_steps=test_generator.samples // BATCH_SIZE
    )
# Out:
# Epoch 1/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 27s 114ms/step - accuracy: 0.3228 - loss: 1.7302 - val_accuracy: 0.2805 - val_loss: 1.4536
# Epoch 2/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3438 - loss: 1.3699 - val_accuracy: 0.0000e+00 - val_loss: 1.2317
# Epoch 3/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 33s 91ms/step - accuracy: 0.3945 - loss: 1.4460 - val_accuracy: 0.5297 - val_loss: 1.0894
# Epoch 4/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 103us/step - accuracy: 0.6250 - loss: 1.0508 - val_accuracy: 0.0323 - val_loss: 1.6782
# Epoch 5/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 90ms/step - accuracy: 0.4295 - loss: 1.3258 - val_accuracy: 0.3812 - val_loss: 1.3630
# Epoch 6/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3125 - loss: 1.3338 - val_accuracy: 0.0968 - val_loss: 1.1808
# Epoch 7/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 97ms/step - accuracy: 0.5173 - loss: 1.1304 - val_accuracy: 0.6914 - val_loss: 0.7732
# Epoch 8/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 121us/step - accuracy: 0.7188 - loss: 0.8033 - val_accuracy: 0.9355 - val_loss: 0.4970
# Epoch 9/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - accuracy: 0.6218 - loss: 0.9150 - val_accuracy: 0.5469 - val_loss: 1.3373
# Epoch 10/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - accuracy: 0.6875 - loss: 0.9040 - val_accuracy: 0.0000e+00 - val_loss: 3.2261
# Epoch 11/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 90ms/step - accuracy: 0.6864 - loss: 0.7763 - val_accuracy: 0.6609 - val_loss: 0.9424
# Epoch 12/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 111us/step - accuracy: 0.5938 - loss: 1.0144 - val_accuracy: 1.0000 - val_loss: 0.0827
# Epoch 13/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 97ms/step - accuracy: 0.7349 - loss: 0.6875 - val_accuracy: 0.7344 - val_loss: 0.6828
# Epoch 14/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.6717 - val_accuracy: 1.0000 - val_loss: 0.1242
# Epoch 15/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - accuracy: 0.7520 - loss: 0.6507 - val_accuracy: 0.5914 - val_loss: 1.0249
# Epoch 16/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 117us/step - accuracy: 0.8750 - loss: 0.3533 - val_accuracy: 0.6774 - val_loss: 0.7560
# Epoch 17/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 96ms/step - accuracy: 0.7720 - loss: 0.6167 - val_accuracy: 0.6789 - val_loss: 0.9874
# Epoch 18/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 125us/step - accuracy: 0.8125 - loss: 0.5116 - val_accuracy: 1.0000 - val_loss: 0.0359
# Epoch 19/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - accuracy: 0.7714 - loss: 0.5846 - val_accuracy: 0.7344 - val_loss: 0.7885
# Epoch 20/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 131us/step - accuracy: 0.8438 - loss: 0.5112 - val_accuracy: 0.7742 - val_loss: 0.6427
# Epoch 21/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 97ms/step - accuracy: 0.7823 - loss: 0.5727 - val_accuracy: 0.4328 - val_loss: 1.8406
# Epoch 22/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s
# Epoch 92/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 140us/step - accuracy: 0.9062 - loss: 0.2148 - val_accuracy: 1.0000 - val_loss: 0.0673
# Epoch 93/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 98ms/step - accuracy: 0.8680 - loss: 0.3597 - val_accuracy: 0.8547 - val_loss: 0.4067
# Epoch 94/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 128us/step - accuracy: 0.8750 - loss: 0.2832 - val_accuracy: 0.9677 - val_loss: 0.0908
# Epoch 95/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 103ms/step - accuracy: 0.8752 - loss: 0.3524 - val_accuracy: 0.8148 - val_loss: 0.5322
# Epoch 96/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 129us/step - accuracy: 0.9375 - loss: 0.3244 - val_accuracy: 0.8710 - val_loss: 0.3099
# Epoch 97/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 98ms/step - accuracy: 0.8704 - loss: 0.3545 - val_accuracy: 0.8773 - val_loss: 0.3415
# Epoch 98/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 132us/step - accuracy: 0.9062 - loss: 0.3569 - val_accuracy: 1.0000 - val_loss: 0.0627
# Epoch 99/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 98ms/step - accuracy: 0.8761 - loss: 0.3546 - val_accuracy: 0.8188 - val_loss: 0.5311
# Epoch 100/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 112us/step - accuracy: 0.8438 - loss: 0.2987 - val_accuracy: 0.8065 - val_loss: 0.5549

# %% [markdown]
# <br>

# %% [markdown]
# # 3.1.2 Train and Test Accuracy

# %%
train_score = model_reg.evaluate(train_generator)
test_score = model_reg.evaluate(test_generator)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 17s 95ms/step - accuracy: 0.8344 - loss: 0.4519
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7840 - loss: 0.6021
# Train Loss:  0.45321720838546753
# Train Accuracy:  0.8377100825309753
# --------------------
# --------------------
# Test Loss:  0.5184415578842163
# Test Accuracy:  0.8192219734191895

# %% [markdown]
# <br>

# %% [markdown]
# # 3.1.3 Plotting Training History

# %%
plt.plot(history_reg.history['accuracy'], label='Training Accuracy')
plt.plot(history_reg.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(history_reg.history['loss'], label='Training Loss')
plt.plot(history_reg.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# <br>

# %%
 model_reg.save('model_reg.keras')

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# # 3.2 Early Stopping
# 100 epochs may seem like overkill, so using early stopping while monitoring validation loss avoids all 100 epochs to run, allowing faster model compiling and run time while still maintaining model performance.

# %% [markdown]
# # 3.2.1 Building and Training the Model

# %%
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam

# Build an optimized CNN model
model_early = Sequential([
    Conv2D(64, kernel_size=(3, 3), activation='tanh', input_shape=(64, 64, 3)),
    MaxPooling2D((2, 2)),

    Conv2D(128, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),

    Conv2D(256, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),

    Conv2D(512, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),

    Flatten(),
    Dense(512, activation='tanh'),
    Dense(128, activation='tanh'),

    Dense(4, activation='softmax')  # Output layer for 4 classes
])

model_early.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',  # Metric to monitor
    patience=20,  # Number of epochs with no improvement after which training will be stopped
    verbose=1,  # Print a message when training is stopped
    restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored metric
)

# %%
history_early = model_early.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=100,  # Increased epochs to get better training results
    validation_data=test_generator,
    validation_steps=test_generator.samples // BATCH_SIZE
    ,callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 22s 103ms/step - accuracy: 0.3988 - loss: 1.4582 - val_accuracy: 0.5844 - val_loss: 0.9490
# Epoch 2/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4688 - loss: 0.9362 - val_accuracy: 0.6129 - val_loss: 0.9295
# Epoch 3/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - accuracy: 0.6285 - loss: 0.8840 - val_accuracy: 0.7570 - val_loss: 0.6741
# Epoch 4/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7188 - loss: 0.5713 - val_accuracy: 0.8065 - val_loss: 0.5006
# Epoch 5/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 96ms/step - accuracy: 0.7171 - loss: 0.7205 - val_accuracy: 0.7469 - val_loss: 0.6115
# Epoch 6/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8438 - loss: 0.4206 - val_accuracy: 0.8710 - val_loss: 0.3289
# Epoch 7/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - accuracy: 0.7681 - loss: 0.6106 - val_accuracy: 0.7242 - val_loss: 0.7168
# Epoch 8/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6875 - loss: 0.9792 - val_accuracy: 0.9355 - val_loss: 0.1556
# Epoch 9/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 90ms/step - accuracy: 0.7932 - loss: 0.5551 - val_accuracy: 0.7719 - val_loss: 0.6360
# Epoch 10/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8125 - loss: 0.6913 - val_accuracy: 0.9677 - val_loss: 0.0856
# Epoch 11/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 95ms/step - accuracy: 0.8150 - loss: 0.4866 - val_accuracy: 0.8094 - val_loss: 0.5156
# Epoch 12/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8125 - loss: 0.6204 - val_accuracy: 0.9677 - val_loss: 0.1252
# Epoch 13/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 92ms/step - accuracy: 0.8406 - loss: 0.4339 - val_accuracy: 0.8477 - val_loss: 0.4077
# Epoch 14/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s
# Epoch 88/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9688 - loss: 0.1700 - val_accuracy: 0.9677 - val_loss: 0.0709
# Epoch 89/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 90ms/step - accuracy: 0.8922 - loss: 0.2928 - val_accuracy: 0.9031 - val_loss: 0.2711
# Epoch 90/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 107us/step - accuracy: 0.9375 - loss: 0.1719 - val_accuracy: 1.0000 - val_loss: 0.0481
# Epoch 91/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - accuracy: 0.9021 - loss: 0.2694 - val_accuracy: 0.8977 - val_loss: 0.2729
# Epoch 92/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 196us/step - accuracy: 0.8125 - loss: 0.5038 - val_accuracy: 0.9677 - val_loss: 0.0636
# Epoch 93/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 95ms/step - accuracy: 0.9058 - loss: 0.2497 - val_accuracy: 0.9148 - val_loss: 0.2320
# Epoch 94/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 126us/step - accuracy: 0.9375 - loss: 0.1617 - val_accuracy: 0.9677 - val_loss: 0.0925
# Epoch 95/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 90ms/step - accuracy: 0.8994 - loss: 0.2772 - val_accuracy: 0.8586 - val_loss: 0.3765
# Epoch 96/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 123us/step - accuracy: 0.8750 - loss: 0.2798 - val_accuracy: 1.0000 - val_loss: 0.0227
# Epoch 97/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 95ms/step - accuracy: 0.8956 - loss: 0.2840 - val_accuracy: 0.9023 - val_loss: 0.2667
# Epoch 98/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - accuracy: 0.8750 - loss: 0.2985 - val_accuracy: 1.0000 - val_loss: 0.0542
# Epoch 99/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 90ms/step - accuracy: 0.9090 - loss: 0.2527 - val_accuracy: 0.9094 - val_loss: 0.2539
# Epoch 100/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 115us/step - accuracy: 0.8750 - loss: 0.2810 - val_accuracy: 0.9677 - val_loss: 0.1346
# Restoring model weights from the end of the best epoch: 84.

# %% [markdown]
# <br>

# %% [markdown]
# # 3.2.2 Train and Test Accuracy

# %%
train_score = model_early.evaluate(train_generator)
test_score = model_early.evaluate(test_generator)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 87ms/step - accuracy: 0.9020 - loss: 0.2598
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8668 - loss: 0.3643
# Train Loss:  0.2693144679069519
# Train Accuracy:  0.9024859666824341
# --------------------
# --------------------
# Test Loss:  0.2788659632205963
# Test Accuracy:  0.8947368264198303

# %% [markdown]
# <br>

# %% [markdown]
# # 3.2.3 Plotting Training History

# %%
plt.plot(history_early.history['accuracy'], label='Training Accuracy')
plt.plot(history_early.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(history_early.history['loss'], label='Training Loss')
plt.plot(history_early.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# <br>

# %%
model_early.save('model_early.keras')

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# # 3.3 Learning Rate
# We aim to reduce learning rate while monitoring validation loss in order to get optimal training and validation scores. A reduced learning rate in theory optimizes performance by forcing the optimizer to make smaller adjustments, fine-tuning parameters for better performance. This inturn stabilizes training and overall performance. Here we have only considered the [ReduceLROnPlateau](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/ReduceLROnPlateau) scheduler into consideration, while some other schedulers include Step Decay, Exponential Decay, Cosine Annealing, Cyclical Learning Rate and many more.

# %% [markdown]
# # 3.3.1 Building and Training the Model

# %%
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam

# Build an optimized CNN model
model_reduce_lr = Sequential([
    Conv2D(64, kernel_size=(3, 3), activation='tanh', input_shape=(64, 64, 3)),
    MaxPooling2D((2, 2)),

    Conv2D(128, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),

    Conv2D(256, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),

    Conv2D(512, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),

    Flatten(),
    Dense(512, activation='tanh'),
    Dense(128, activation='tanh'),

    Dense(4, activation='softmax')  # Output layer for 4 classes
])

model_reduce_lr.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow import keras
reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',  # Metric to monitor
    factor=0.1,  # Factor by which the learning rate will be reduced
    patience=10,  # Number of epochs with no improvement after which learning rate will be reduced
    verbose=1,  # Print messages when learning rate is reduced
    min_delta=0.0001, # Minimum change in the monitored quantity to qualify as an improvement.
    cooldown=0, # Number of epochs to wait before resuming normal operation after lr has been reduced.
    min_lr=0,  # Lower bound on the learning rate.
)

# %%
history_reduce_lr = model_reduce_lr.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=100,  # Increased epochs to get better training results
    validation_data=test_generator,
    validation_steps=test_generator.samples // BATCH_SIZE
    ,callbacks=[reduce_lr])
# Out:
# Epoch 1/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 31s 149ms/step - accuracy: 0.4064 - loss: 1.4207 - val_accuracy: 0.5922 - val_loss: 1.0198 - learning_rate: 0.0010
# Epoch 2/100
#   1/178 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6562 - loss: 0.8762
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6562 - loss: 0.8762 - val_accuracy: 0.9355 - val_loss: 0.3776 - learning_rate: 0.0010
# Epoch 3/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.6431 - loss: 0.8543 - val_accuracy: 0.7125 - val_loss: 0.7437 - learning_rate: 0.0010
# Epoch 4/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 148us/step - accuracy: 0.7500 - loss: 0.5661 - val_accuracy: 1.0000 - val_loss: 0.0960 - learning_rate: 0.0010
# Epoch 5/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 102ms/step - accuracy: 0.7387 - loss: 0.6531 - val_accuracy: 0.7312 - val_loss: 0.7110 - learning_rate: 0.0010
# Epoch 6/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 142us/step - accuracy: 0.7812 - loss: 0.4840 - val_accuracy: 1.0000 - val_loss: 0.0974 - learning_rate: 0.0010
# Epoch 7/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 96ms/step - accuracy: 0.7660 - loss: 0.6023 - val_accuracy: 0.7891 - val_loss: 0.6008 - learning_rate: 0.0010
# Epoch 8/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 139us/step - accuracy: 0.8438 - loss: 0.4553 - val_accuracy: 0.8710 - val_loss: 0.3939 - learning_rate: 0.0010
# Epoch 9/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.7910 - loss: 0.5580 - val_accuracy: 0.7758 - val_loss: 0.5492 - learning_rate: 0.0010
# Epoch 10/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 144us/step - accuracy: 0.7500 - loss: 0.5902 - val_accuracy: 1.0000 - val_loss: 0.0475 - learning_rate: 0.0010
# Epoch 11/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 97ms/step - accuracy: 0.8314 - loss: 0.4779 - val_accuracy: 0.8203 - val_loss: 0.4582 - learning_rate: 0.0010
# Epoch 12/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 299us/step - accuracy: 0.7500 - loss: 0.7113 - val_accuracy: 0.9677 - val_loss: 0.1062 - learning_rate: 0.0010
# Epoch 13/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 99ms/step - accuracy: 0.8334 - loss: 0.4586 - val_accuracy: 0.8117 - val_loss: 0.5173 - learning_rate: 0.0010
# Epoch 14/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 143us/step - accuracy: 0.7812 - loss: 0.6108 - val_accuracy: 0.9677 - val_loss: 0.1378 - learning_rate: 0.0010
# Epoch 15/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 97ms/step - accuracy: 0.8347 - loss: 0.4580 - val_accuracy: 0.8047 - val_loss: 0.5749 - learning_rate: 0.0010
# Epoch 16/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step - accuracy: 0.9688 - loss: 0.2437 - val_accuracy: 1.0000 - val_loss: 0.0291 - learning_rate: 0.0010
# Epoch 17/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 99ms/step - accuracy: 0.8521 - loss: 0.4056 - val_accuracy: 0.8547 - val_loss: 0.3860 - learning_rate: 0.0010
# Epoch 18/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 112us/step - accuracy: 0.8438 - loss: 0.3476 - val_accuracy: 1.0000 - val_loss: 0.0879 - learning_rate: 0.0010
# Epoch 19/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 96ms/step - accuracy: 0.8568 - loss: 0.3871 - val_accuracy: 0.8422 - val_loss: 0.4407 - learning_rate: 0.0010
# Epoch 20/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 120us/step - accuracy: 0.8125 - loss: 0.4568 - val_accuracy: 0.9677 - val_loss: 0.0994 - learning_rate: 0.0010
# Epoch 21/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 101ms/step - accuracy: 0.8656 - loss: 0.3722 - val_accuracy: 0.8805 - val_loss: 0.3448 - learning_rate: 0.0010
# Epoch 22/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 130us/step - accuracy: 0.8125 - loss: 0.5090 - val_accuracy: 1.0000 - val_loss: 0.0425 - learning_rate: 0.0010
# Epoch 23/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 99ms/step - accuracy: 0.8720 - loss: 0.3516 - val_accuracy: 0.8422 - val_loss: 0.4313 - learning_rate: 0.0010
# Epoch 24/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 164us/step - accuracy: 0.8438 - loss: 0.4380 - val_accuracy: 1.0000 - val_loss: 0.0231 - learning_rate: 0.0010
# Epoch 25/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 105ms/step - accuracy: 0.8613 - loss: 0.3837 - val_accuracy: 0.8500 - val_loss: 0.3990 - learning_rate: 0.0010
# Epoch 26/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 151us/step - accuracy: 1.0000 - loss: 0.1851 - val_accuracy: 1.0000 - val_loss: 0.0515 - learning_rate: 0.0010
# Epoch 27/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.8744 - loss: 0.3282 - val_accuracy: 0.8883 - val_loss: 0.3120 - learning_rate: 0.0010
# Epoch 28/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 215us/step - accuracy: 1.0000 - loss: 0.0855 - val_accuracy: 1.0000 - val_loss: 0.0384 - learning_rate: 0.0010
# Epoch 29/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 102ms/step - accuracy: 0.8849 - loss: 0.3073 - val_accuracy: 0.8758 - val_loss: 0.3282 - learning_rate: 0.0010
# Epoch 30/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8750 - loss: 0.2961 - val_accuracy: 1.0000 - val_loss: 0.0333 - learning_rate: 0.0010
# Epoch 31/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 98ms/step - accuracy: 0.8837 - loss: 0.3255 - val_accuracy: 0.8703 - val_loss: 0.3328 - learning_rate: 0.0010
# Epoch 32/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 135us/step - accuracy: 0.8438 - loss: 0.3860 - val_accuracy: 0.9677 - val_loss: 0.1244 - learning_rate: 0.0010
# Epoch 33/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 99ms/step - accuracy: 0.8780 - loss: 0.3345 - val_accuracy: 0.8680 - val_loss: 0.3527 - learning_rate: 0.0010
# Epoch 34/100
#   1/178 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9062 - loss: 0.2467
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9062 - loss: 0.2467 - val_accuracy: 0.9677 - val_loss: 0.1461 - learning_rate: 0.0010
# Epoch 35/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 98ms/step - accuracy: 0.8987 - loss: 0.2857 - val_accuracy: 0.8789 - val_loss: 0.3304 - learning_rate: 1.0000e-04
# Epoch 36/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 149us/step - accuracy: 0.7812 - loss: 0.3858 - val_accuracy: 1.0000 - val_loss: 0.0401 - learning_rate: 1.0000e-04
# Epoch 37/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 103ms/step - accuracy: 0.9090 - loss: 0.2370 - val_accuracy: 0.8820 - val_loss: 0.3009 - learning_rate: 1.0000e-04
# Epoch 38/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 149us/step - accuracy: 0.9688 - loss: 0.1483 - val_accuracy: 1.0000 - val_loss: 0.0227 - learning_rate: 1.0000e-04
# Epoch 39/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 98ms/step - accuracy: 0.9201 - loss: 0.2116 - val_accuracy: 0.8781 - val_loss: 0.3334 - learning_rate: 1.0000e-04
# Epoch 40/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 235us/step - accuracy: 0.9375 - loss: 0.1715 - val_accuracy: 1.0000 - val_loss: 0.0284 - learning_rate: 1.0000e-04
# Epoch 41/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 98ms/step - accuracy: 0.9205 - loss: 0.2134 - val_accuracy: 0.8906 - val_loss: 0.2878 - learning_rate: 1.0000e-04
# Epoch 42/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 191us/step - accuracy: 0.9375 - loss: 0.2433 - val_accuracy: 0.9677 - val_loss: 0.0410 - learning_rate: 1.0000e-04
# Epoch 43/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 98ms/step - accuracy: 0.9328 - loss: 0.1987 - val_accuracy: 0.9148 - val_loss: 0.2350 - learning_rate: 1.0000e-04
# Epoch 44/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 202us/step - accuracy: 0.9375 - loss: 0.1699 - val_accuracy: 1.0000 - val_loss: 0.0454 - learning_rate: 1.0000e-04
# Epoch 45/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 97ms/step - accuracy: 0.9306 - loss: 0.1920 - val_accuracy: 0.8891 - val_loss: 0.2928 - learning_rate: 1.0000e-04
# Epoch 46/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9062 - loss: 0.2155 - val_accuracy: 1.0000 - val_loss: 0.0142 - learning_rate: 1.0000e-04
# Epoch 47/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 103ms/step - accuracy: 0.9272 - loss: 0.1963 - val_accuracy: 0.9133 - val_loss: 0.2467 - learning_rate: 1.0000e-04
# Epoch 48/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 249us/step - accuracy: 0.9688 - loss: 0.1385 - val_accuracy: 1.0000 - val_loss: 0.0247 - learning_rate: 1.0000e-04
# Epoch 49/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.9379 - loss: 0.1756 - val_accuracy: 0.8797 - val_loss: 0.3330 - learning_rate: 1.0000e-04
# Epoch 50/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 133us/step - accuracy: 0.8125 - loss: 0.4641 - val_accuracy: 1.0000 - val_loss: 0.0170 - learning_rate: 1.0000e-04
# Epoch 51/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.9296 - loss: 0.1914 - val_accuracy: 0.9016 - val_loss: 0.2713 - learning_rate: 1.0000e-04
# Epoch 52/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 206us/step - accuracy: 0.9688 - loss: 0.0859 - val_accuracy: 0.9677 - val_loss: 0.0400 - learning_rate: 1.0000e-04
# Epoch 53/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 100ms/step - accuracy: 0.9342 - loss: 0.1845 - val_accuracy: 0.9125 - val_loss: 0.2602 - learning_rate: 1.0000e-04
# Epoch 54/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 132us/step - accuracy: 0.9375 - loss: 0.1109 - val_accuracy: 1.0000 - val_loss: 0.0190 - learning_rate: 1.0000e-04
# Epoch 55/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.9424 - loss: 0.1583 - val_accuracy: 0.9008 - val_loss: 0.2468 - learning_rate: 1.0000e-04
# Epoch 56/100
#   1/178 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.9062 - loss: 0.1654
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9062 - loss: 0.1654 - val_accuracy: 0.9677 - val_loss: 0.0847 - learning_rate: 1.0000e-04
# Epoch 57/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 98ms/step - accuracy: 0.9410 - loss: 0.1655 - val_accuracy: 0.9203 - val_loss: 0.2220 - learning_rate: 1.0000e-05
# Epoch 58/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9375 - loss: 0.1954 - val_accuracy: 0.9677 - val_loss: 0.0554 - learning_rate: 1.0000e-05
# Epoch 59/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 101ms/step - accuracy: 0.9482 - loss: 0.1573 - val_accuracy: 0.9180 - val_loss: 0.2328 - learning_rate: 1.0000e-05
# Epoch 60/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 243us/step - accuracy: 0.8438 - loss: 0.3369 - val_accuracy: 1.0000 - val_loss: 0.0367 - learning_rate: 1.0000e-05
# Epoch 61/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 96ms/step - accuracy: 0.9392 - loss: 0.1646 - val_accuracy: 0.9148 - val_loss: 0.2341 - learning_rate: 1.0000e-05
# Epoch 62/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 177us/step - accuracy: 0.9375 - loss: 0.1202 - val_accuracy: 0.9677 - val_loss: 0.0473 - learning_rate: 1.0000e-05
# Epoch 63/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 101ms/step - accuracy: 0.9459 - loss: 0.1577 - val_accuracy: 0.9117 - val_loss: 0.2328 - learning_rate: 1.0000e-05
# Epoch 64/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 113us/step - accuracy: 0.9375 - loss: 0.1319 - val_accuracy: 1.0000 - val_loss: 0.0397 - learning_rate: 1.0000e-05
# Epoch 65/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 96ms/step - accuracy: 0.9458 - loss: 0.1523 - val_accuracy: 0.9117 - val_loss: 0.2412 - learning_rate: 1.0000e-05
# Epoch 66/100
#   1/178 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 1.0000 - loss: 0.0358
# Epoch 66: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0358 - val_accuracy: 1.0000 - val_loss: 0.0307 - learning_rate: 1.0000e-05
# Epoch 67/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 103ms/step - accuracy: 0.9473 - loss: 0.1551 - val_accuracy: 0.9133 - val_loss: 0.2399 - learning_rate: 1.0000e-06
# Epoch 68/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 227us/step - accuracy: 0.9062 - loss: 0.1844 - val_accuracy: 1.0000 - val_loss: 0.0317 - learning_rate: 1.0000e-06
# Epoch 69/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.9462 - loss: 0.1571 - val_accuracy: 0.9133 - val_loss: 0.2403 - learning_rate: 1.0000e-06
# Epoch 70/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9375 - loss: 0.1691 - val_accuracy: 1.0000 - val_loss: 0.0311 - learning_rate: 1.0000e-06
# Epoch 71/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 104ms/step - accuracy: 0.9442 - loss: 0.1635 - val_accuracy: 0.9133 - val_loss: 0.2409 - learning_rate: 1.0000e-06
# Epoch 72/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 128us/step - accuracy: 0.9688 - loss: 0.1650 - val_accuracy: 1.0000 - val_loss: 0.0319 - learning_rate: 1.0000e-06
# Epoch 73/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 97ms/step - accuracy: 0.9495 - loss: 0.1542 - val_accuracy: 0.9133 - val_loss: 0.2377 - learning_rate: 1.0000e-06
# Epoch 74/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 135us/step - accuracy: 0.9375 - loss: 0.1121 - val_accuracy: 1.0000 - val_loss: 0.0321 - learning_rate: 1.0000e-06
# Epoch 75/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 102ms/step - accuracy: 0.9417 - loss: 0.1595 - val_accuracy: 0.9148 - val_loss: 0.2367 - learning_rate: 1.0000e-06
# Epoch 76/100
#   1/178 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9375 - loss: 0.1548
# Epoch 76: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9375 - loss: 0.1548 - val_accuracy: 1.0000 - val_loss: 0.0325 - learning_rate: 1.0000e-06
# Epoch 77/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.9411 - loss: 0.1634 - val_accuracy: 0.9148 - val_loss: 0.2367 - learning_rate: 1.0000e-07
# Epoch 78/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 128us/step - accuracy: 0.8750 - loss: 0.2060 - val_accuracy: 1.0000 - val_loss: 0.0327 - learning_rate: 1.0000e-07
# Epoch 79/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 101ms/step - accuracy: 0.9452 - loss: 0.1528 - val_accuracy: 0.9148 - val_loss: 0.2366 - learning_rate: 1.0000e-07
# Epoch 80/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 151us/step - accuracy: 0.9688 - loss: 0.0954 - val_accuracy: 1.0000 - val_loss: 0.0327 - learning_rate: 1.0000e-07
# Epoch 81/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.9466 - loss: 0.1652 - val_accuracy: 0.9148 - val_loss: 0.2366 - learning_rate: 1.0000e-07
# Epoch 82/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 144us/step - accuracy: 1.0000 - loss: 0.0764 - val_accuracy: 1.0000 - val_loss: 0.0327 - learning_rate: 1.0000e-07
# Epoch 83/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 103ms/step - accuracy: 0.9443 - loss: 0.1588 - val_accuracy: 0.9148 - val_loss: 0.2366 - learning_rate: 1.0000e-07
# Epoch 84/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9375 - loss: 0.1662 - val_accuracy: 1.0000 - val_loss: 0.0328 - learning_rate: 1.0000e-07
# Epoch 85/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 97ms/step - accuracy: 0.9518 - loss: 0.1497 - val_accuracy: 0.9148 - val_loss: 0.2363 - learning_rate: 1.0000e-07
# Epoch 86/100
#   1/178 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.8438 - loss: 0.2918
# Epoch 86: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8438 - loss: 0.2918 - val_accuracy: 1.0000 - val_loss: 0.0329 - learning_rate: 1.0000e-07
# Epoch 87/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 104ms/step - accuracy: 0.9429 - loss: 0.1584 - val_accuracy: 0.9148 - val_loss: 0.2363 - learning_rate: 1.0000e-08
# Epoch 88/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 201us/step - accuracy: 0.8125 - loss: 0.4519 - val_accuracy: 1.0000 - val_loss: 0.0329 - learning_rate: 1.0000e-08
# Epoch 89/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 97ms/step - accuracy: 0.9411 - loss: 0.1693 - val_accuracy: 0.9148 - val_loss: 0.2363 - learning_rate: 1.0000e-08
# Epoch 90/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 137us/step - accuracy: 0.9062 - loss: 0.1783 - val_accuracy: 1.0000 - val_loss: 0.0329 - learning_rate: 1.0000e-08
# Epoch 91/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 103ms/step - accuracy: 0.9439 - loss: 0.1631 - val_accuracy: 0.9148 - val_loss: 0.2363 - learning_rate: 1.0000e-08
# Epoch 92/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 129us/step - accuracy: 0.9375 - loss: 0.1841 - val_accuracy: 1.0000 - val_loss: 0.0329 - learning_rate: 1.0000e-08
# Epoch 93/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 98ms/step - accuracy: 0.9453 - loss: 0.1445 - val_accuracy: 0.9148 - val_loss: 0.2363 - learning_rate: 1.0000e-08
# Epoch 94/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 113us/step - accuracy: 1.0000 - loss: 0.0357 - val_accuracy: 1.0000 - val_loss: 0.0329 - learning_rate: 1.0000e-08
# Epoch 95/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 103ms/step - accuracy: 0.9373 - loss: 0.1636 - val_accuracy: 0.9148 - val_loss: 0.2363 - learning_rate: 1.0000e-08
# Epoch 96/100
#   1/178 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.9688 - loss: 0.0943
# Epoch 96: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 206us/step - accuracy: 0.9688 - loss: 0.0943 - val_accuracy: 1.0000 - val_loss: 0.0329 - learning_rate: 1.0000e-08
# Epoch 97/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.9414 - loss: 0.1606 - val_accuracy: 0.9148 - val_loss: 0.2363 - learning_rate: 1.0000e-09
# Epoch 98/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 143us/step - accuracy: 0.9375 - loss: 0.2178 - val_accuracy: 1.0000 - val_loss: 0.0329 - learning_rate: 1.0000e-09
# Epoch 99/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.9448 - loss: 0.1455 - val_accuracy: 0.9148 - val_loss: 0.2363 - learning_rate: 1.0000e-09
# Epoch 100/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 193us/step - accuracy: 0.9375 - loss: 0.2184 - val_accuracy: 1.0000 - val_loss: 0.0329 - learning_rate: 1.0000e-09

# %% [markdown]
# <br>

# %% [markdown]
# # 3.3.2 Train and Test Accuracy

# %%
train_score = model_reduce_lr.evaluate(train_generator)
test_score = model_reduce_lr.evaluate(test_generator)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 17s 95ms/step - accuracy: 0.9432 - loss: 0.1622
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.8845 - loss: 0.3196
# Train Loss:  0.15603503584861755
# Train Accuracy:  0.9455532431602478
# --------------------
# --------------------
# Test Loss:  0.23148824274539948
# Test Accuracy:  0.9168573617935181

# %% [markdown]
# <br>

# %% [markdown]
# # 3.3.3 Plotting Training History

# %%
plt.plot(history_reduce_lr.history['accuracy'], label='Training Accuracy')
plt.plot(history_reduce_lr.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(history_reduce_lr.history['loss'], label='Training Loss')
plt.plot(history_reduce_lr.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# <br>

# %%
model_reduce_lr.save('model_reduce_lr.keras')

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# # 3.4 Xavier Initialisation
# Also known as __Glorot Initialisation__, it is a weight initialisation method that ensures constant variance of inputs and outputs of each layer. It is mostly used in conjuntion with __tanh__ activation function to tackle the vanishing or exploding gradient problem common in deep networks. The function in python is [GlorotUniform]((https://www.tensorflow.org/api_docs/python/tf/keras/initializers/GlorotUniform) and it draws samples from a uniform distribution within $ [-limit, limit] $, where $$ limit = \sqrt{\frac{6}{fan_{in} + fan_{out}}} $$
# <br>
# $ fan_{in} $ is the number of input units in the weight tensor and $ fan_{out} $ is the number of output units.

# %% [markdown]
# # 3.4.1 Building and Training the Model

# %%
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import GlorotUniform

# Build an optimized CNN model
model_xavier = Sequential([
    Conv2D(64, kernel_size=(3, 3), activation='tanh', input_shape=(64, 64, 3)),
    MaxPooling2D((2, 2)),

    Conv2D(128, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),

    Conv2D(256, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),

    Conv2D(512, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),

    Flatten(),
    Dense(512, activation='tanh', kernel_initializer=GlorotUniform()),
    Dense(128, activation='tanh', kernel_initializer=GlorotUniform()),

    Dense(4, activation='softmax')  # Output layer for 4 classes
])

model_xavier.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history_xavier = model_xavier.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=100,  # Increased epochs to get better training results
    validation_data=test_generator,
    validation_steps=test_generator.samples // BATCH_SIZE
)
# Out:
# Epoch 1/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.3795 - loss: 1.4283 - val_accuracy: 0.6281 - val_loss: 0.9653
# Epoch 2/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6562 - loss: 0.8744 - val_accuracy: 0.9355 - val_loss: 0.3417
# Epoch 3/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 37s 90ms/step - accuracy: 0.6434 - loss: 0.8660 - val_accuracy: 0.6828 - val_loss: 0.7877
# Epoch 4/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 117us/step - accuracy: 0.6562 - loss: 0.6041 - val_accuracy: 0.9677 - val_loss: 0.1150
# Epoch 5/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - accuracy: 0.7286 - loss: 0.6953 - val_accuracy: 0.7117 - val_loss: 0.7561
# Epoch 6/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6875 - loss: 0.5685 - val_accuracy: 0.9355 - val_loss: 0.1623
# Epoch 7/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 89ms/step - accuracy: 0.7740 - loss: 0.6054 - val_accuracy: 0.7898 - val_loss: 0.5627
# Epoch 8/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 107us/step - accuracy: 0.7188 - loss: 0.7373 - val_accuracy: 0.9677 - val_loss: 0.1904
# Epoch 9/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - accuracy: 0.8114 - loss: 0.5043 - val_accuracy: 0.8258 - val_loss: 0.4474
# Epoch 10/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 117us/step - accuracy: 0.8125 - loss: 0.4841 - val_accuracy: 0.9032 - val_loss: 0.2765
# Epoch 11/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 90ms/step - accuracy: 0.8277 - loss: 0.4683 - val_accuracy: 0.8133 - val_loss: 0.4864
# Epoch 12/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 122us/step - accuracy: 0.7188 - loss: 0.5637 - val_accuracy: 1.0000 - val_loss: 0.0341
# Epoch 13/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 92ms/step - accuracy: 0.8488 - loss: 0.4188 - val_accuracy: 0.8031 - val_loss: 0.6088
# Epoch 14/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8438 - loss: 0.3285 - val_accuracy: 1.0000 - val_loss: 0.0645
# Epoch 15/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 23s 106ms/step - accuracy: 0
100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - accuracy: 0.9062 - loss: 0.2606 - val_accuracy: 0.8938 - val_loss: 0.2778
# Epoch 80/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 121us/step - accuracy: 0.9062 - loss: 0.2977 - val_accuracy: 0.9677 - val_loss: 0.0707
# Epoch 81/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 95ms/step - accuracy: 0.9048 - loss: 0.2692 - val_accuracy: 0.9000 - val_loss: 0.2777
# Epoch 82/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 109us/step - accuracy: 0.9688 - loss: 0.1398 - val_accuracy: 0.9677 - val_loss: 0.1209
# Epoch 83/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - accuracy: 0.8941 - loss: 0.2882 - val_accuracy: 0.9086 - val_loss: 0.2459
# Epoch 84/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 115us/step - accuracy: 0.9375 - loss: 0.2544 - val_accuracy: 1.0000 - val_loss: 0.0090
# Epoch 85/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 96ms/step - accuracy: 0.8975 - loss: 0.2821 - val_accuracy: 0.8898 - val_loss: 0.2806
# Epoch 86/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9062 - loss: 0.2837 - val_accuracy: 1.0000 - val_loss: 0.0303
# Epoch 87/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - accuracy: 0.9064 - loss: 0.2624 - val_accuracy: 0.8828 - val_loss: 0.3203
# Epoch 88/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 127us/step - accuracy: 0.8750 - loss: 0.4459 - val_accuracy: 1.0000 - val_loss: 0.0174
# Epoch 89/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 22s 95ms/step - accuracy: 0.9141 - loss: 0.2344 - val_accuracy: 0.9008 - val_loss: 0.2650
# Epoch 90/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 127us/step - accuracy: 0.8750 - loss: 0.4129 - val_accuracy: 0.9677 - val_loss: 0.0532
# Epoch 91/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 90ms/step - accuracy: 0.9156 - loss: 0.2421 - val_accuracy: 0.8633 - val_loss: 0.3498
# Epoch 92/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 125us/step - accuracy: 0.8750 - loss: 0.3284 - val_accuracy: 1.0000 - val_loss: 0.0134
# Epoch 93/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 90ms/step - accuracy: 0.9134 - loss: 0.2575 - val_accuracy: 0.9117 - val_loss: 0.2502
# Epoch 94/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - accuracy: 0.9688 - loss: 0.1156 - val_accuracy: 0.9677 - val_loss: 0.0800
# Epoch 95/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 90ms/step - accuracy: 0.9018 - loss: 0.2699 - val_accuracy: 0.9086 - val_loss: 0.2707
# Epoch 96/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - accuracy: 0.9062 - loss: 0.1548 - val_accuracy: 0.9677 - val_loss: 0.0863
# Epoch 97/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - accuracy: 0.9044 - loss: 0.2666 - val_accuracy: 0.9195 - val_loss: 0.2270
# Epoch 98/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 121us/step - accuracy: 0.8750 - loss: 0.3352 - val_accuracy: 0.9677 - val_loss: 0.0581
# Epoch 99/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 96ms/step - accuracy: 0.9090 - loss: 0.2425 - val_accuracy: 0.8922 - val_loss: 0.2751
# Epoch 100/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 111us/step - accuracy: 0.9375 - loss: 0.1690 - val_accuracy: 1.0000 - val_loss: 0.0555

# %% [markdown]
# <br>

# %% [markdown]
# # 3.4.2 Train and Test Accuracy

# %%
train_score = model_xavier.evaluate(train_generator)
test_score = model_xavier.evaluate(test_generator)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 86ms/step - accuracy: 0.9209 - loss: 0.2213
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8635 - loss: 0.3448
# Train Loss:  0.22365914285182953
# Train Accuracy:  0.9219187498092651
# --------------------
# --------------------
# Test Loss:  0.2598733901977539
# Test Accuracy:  0.8985507488250732

# %% [markdown]
# <br>

# %% [markdown]
# # 3.4.3 Plotting Training History

# %%
plt.plot(history_xavier.history['accuracy'], label='Training Accuracy')
plt.plot(history_xavier.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(history_xavier.history['loss'], label='Training Loss')
plt.plot(history_xavier.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# # 4. Evaluating on Test Data
# All the models are now evaluated on the test data, in specific I have taken random images from the __Testing__ subfolder and used the trained models to predict whether the image is 1 of the 4 classifications of brain tumors. There is no perfect way to choose the best model, but I have simply portrayed the comparisons of the model's ability to predict on unseen data. In fact multiple images can be chosen to test prediction.

# %% [markdown]
# # 4.1 Base Model

# %%
from tensorflow import keras

from tensorflow.keras.preprocessing import image

def predict_image(model, img_path, target_size=(64, 64)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0  # normalize as trained

    prediction = model_base.predict(img_array)
    class_index = np.argmax(prediction, axis=1)[0]
    class_label = list(train_generator.class_indices.keys())[class_index]
    prediction_score = prediction[0][class_index]

    return class_label, prediction_score

# Predict a new image
img_path = keras.utils.load_img('/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/meningioma/Te-me_0282.jpg')
plt.imshow(img_path)
img = '/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/meningioma/Te-me_0282.jpg'
predicted_label, prediction_score = predict_image(model_base, img)
print(f"The predicted label is: {predicted_label}")
print(f"Prediction score for {predicted_label}: {prediction_score:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 663ms/step
# The predicted label is: meningioma
# Prediction score for meningioma: 0.9987

# %% [markdown]
# <br>

# %% [markdown]
# # 4.2 Model with Regularisation

# %%
from tensorflow import keras

from tensorflow.keras.preprocessing import image

def predict_image(model, img_path, target_size=(64, 64)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0  # normalize as trained

    prediction = model_reg.predict(img_array)
    class_index = np.argmax(prediction, axis=1)[0]
    class_label = list(train_generator.class_indices.keys())[class_index]
    prediction_score = prediction[0][class_index]

    return class_label, prediction_score

# Predict a new image
img_path = keras.utils.load_img('/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/glioma/Te-gl_0263.jpg')
plt.imshow(img_path)
img = '/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/glioma/Te-gl_0263.jpg'
predicted_label, prediction_score = predict_image(model_reg, img)
print(f"The predicted label is: {predicted_label}")
print(f"Prediction score for {predicted_label}: {prediction_score:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# The predicted label is: glioma
# Prediction score for glioma: 0.8461

# %% [markdown]
# <br>

# %% [markdown]
# # 4.3 Model with Early Stopping

# %%
from tensorflow import keras

from tensorflow.keras.preprocessing import image

def predict_image(model, img_path, target_size=(64, 64)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0  # normalize as trained

    prediction = model_early.predict(img_array)
    class_index = np.argmax(prediction, axis=1)[0]
    class_label = list(train_generator.class_indices.keys())[class_index]
    prediction_score = prediction[0][class_index]

    return class_label, prediction_score

# Predict a new image
img_path = keras.utils.load_img('/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/notumor/Te-no_0185.jpg')
plt.imshow(img_path)
img = '/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/notumor/Te-no_0185.jpg'
predicted_label, prediction_score = predict_image(model_early, img)
print(f"The predicted label is: {predicted_label}")
print(f"Prediction score for {predicted_label}: {prediction_score:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# The predicted label is: notumor
# Prediction score for notumor: 0.9940

# %% [markdown]
# <br>

# %% [markdown]
# # 4.3 Model with Reduced Learning Rate

# %%
from tensorflow import keras

from tensorflow.keras.preprocessing import image

def predict_image(model, img_path, target_size=(64, 64)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0  # normalize as trained

    prediction = model_reduce_lr.predict(img_array)
    class_index = np.argmax(prediction, axis=1)[0]
    class_label = list(train_generator.class_indices.keys())[class_index]
    prediction_score = prediction[0][class_index]

    return class_label, prediction_score

# Predict a new image
img_path = keras.utils.load_img('/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/pituitary/Te-pi_0139.jpg')
plt.imshow(img_path)
img = '/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/pituitary/Te-pi_0139.jpg'
predicted_label, prediction_score = predict_image(model_reduce_lr, img)
print(f"The predicted label is: {predicted_label}")
print(f"Prediction score for {predicted_label}: {prediction_score:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# The predicted label is: pituitary
# Prediction score for pituitary: 0.9886

# %% [markdown]
# <br>

# %% [markdown]
# # 4.4 Model with Xavier Initialisation

# %%
from tensorflow import keras

from tensorflow.keras.preprocessing import image

def predict_image(model, img_path, target_size=(64, 64)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0  # normalize as trained

    prediction = model_xavier.predict(img_array)
    class_index = np.argmax(prediction, axis=1)[0]
    class_label = list(train_generator.class_indices.keys())[class_index]
    prediction_score = prediction[0][class_index]

    return class_label, prediction_score

# Predict a new image
img_path = keras.utils.load_img('/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/meningioma/Te-me_0034.jpg')
plt.imshow(img_path)
img = '/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/meningioma/Te-me_0034.jpg'
predicted_label, prediction_score = predict_image(model_xavier, img)
print(f"The predicted label is: {predicted_label}")
print(f"Prediction score for {predicted_label}: {prediction_score:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# The predicted label is: meningioma
# Prediction score for meningioma: 0.9673

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# # 5. Conclusion
# On observing the various models i.e., base model, adding regularisation, early stopping, reduced learning rate scheduler and weight initialisation, it is observed that there are similar characteristics to most models, one being the representations of the training and validation accuracies and scores. On graphical visualisation, we can see an oscillatory behaviour which could be caused by multiple reasons. One could be due to the learning rate being 0.001, causing instability and large fluctuations, and it is observed in the graph for reduced learning rate, a more stable and less oscillatory trend is observed, especially with respect to the training accuracies and losses. Since I have not investiagted on the batch size, this could also be the reason as smaller batch sizes can introduce noise in gradient updates.
# <br>
# The other thing to observe is that on random selection of images from the testing folder, it is clear to see that all models perform well except maybe the model with regularisation. Now, since we have chosen the images at random, it could be that this model predicts other images well, but this cannot be guaranteed. In fact even for the "well-performing" models, prediction results as seen here is not conclusive proof that the model predicts every kind of image accurately. But, computationally this will be extremely tedious, and hence why it is not included.
# <br>
# There is obviously no "best" model that ever be made, but out of the sample of models we have created, it is obvious by the training and testing accuracy scores that the __Reduced Learning Rate Model__ is relatively a more viable option (based on training, testing, and validation accuracies).
