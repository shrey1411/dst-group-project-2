# %% [markdown]
# <a href="https://colab.research.google.com/github/vivekp12/dst-group-project-2/blob/main/VivekP/ForConsistency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# >[Introduction](#scrollTo=rKCfp20CeRoj)
#
# >[Requirements](#scrollTo=4tjtYwXiTGbg)
#
# >[1.1 Data Augmentation](#scrollTo=Db4dvLsLU0UY)
#
# >[1.2 Train and Test Splitting](#scrollTo=ZP8zGYwkUv6z)
#
# >[Model Training (Base Model)](#scrollTo=mj1aL4LyWNlZ)
#
# >[2.1 Building and training the Model](#scrollTo=hrWYKmiEVr4S)
#
# >[2.2 Train and Test Accuracy](#scrollTo=dQ9sN6o4fVEc)
#
# >[2.3 Plotting Training History](#scrollTo=Uu83BmTBftLA)
#
# >[Paramter Tuning](#scrollTo=XmZNI5WWXyW5)
#
# >[3.1 Regularisation (Batch Normalisation and Dropout)](#scrollTo=mdow1495uRyJ)
#
# >[3.1.1 Building and Training the Model](#scrollTo=EvOT0wmAvAjO)
#
# >[3.1.2 Train and Test Accuracy](#scrollTo=0T3yz2nHvQhY)
#
# >[3.1.3 Plotting Training History](#scrollTo=AuvTYjPtvcO3)
#
# >[3.2 Regularisation (Early Stopping)](#scrollTo=mbpE8SoT077u)
#
# >[3.2.1 Building and Training the Model](#scrollTo=Eh0amf4OYEoV)
#
# >[3.2.2 Train and Test Accuracy](#scrollTo=UbxaFmSlYWMs)
#
# >[3.2.3 Plotting Training History](#scrollTo=n6OdaKHTZUnU)
#
# >[3.3 Learning Rate Scheduler](#scrollTo=Kg2qgirW15y2)
#
# >[3.3.1 Building and Training the Model](#scrollTo=kmXSLbNdZtFe)
#
# >[3.3.2 Train and Test Accuracy](#scrollTo=xi5BDDbIZ7SS)
#
# >[3.3.3 Plotting Training History](#scrollTo=HOI7dj0TaKuX)
#
# >[3.4 Weight Initialisation](#scrollTo=qBTD-GeqP7WE)
#
# >[3.4.1 Building and Training the Model](#scrollTo=q_R_yJjeSQnq)
#
# >[3.4.2 Train and Test Accuracy](#scrollTo=NP3zt-sHSetx)
#
# >[3.4.3 Plotting Training History](#scrollTo=RXaz3ADKSjoN)
#
# >[3.5 Final Model](#scrollTo=jmC4OTcAIKtd)
#
# >[The concept of "Best Model"](#scrollTo=8wNNNn4dRj_1)
#
# >[4.1 Upscaling using the final model](#scrollTo=Jf6fbSlJT87R)
#
# >[Evaluating on Test Data](#scrollTo=ztNRGf3QSsSl)
#
# >[5.1 Base Model](#scrollTo=VNn1p1J946tB)
#
# >[5.2 Model with Regularisation](#scrollTo=EWrhvpbG5pKE)
#
# >[5.3 Model with Early Stopping](#scrollTo=khKqgst35w_s)
#
# >[5.4 Model with Reduced Learning Rate](#scrollTo=czw6xcZBCbcg)
#
# >[5.5 Model with Xavier Initialisation](#scrollTo=uRcHwNoM52YA)
#
# >[5.6 Final Model](#scrollTo=QVfD-6S3dVJX)
#
# >[5.7 Model for Scaled Image](#scrollTo=YrlqeSkM2kZ6)
#
# >[Conclusion](#scrollTo=0lU9iP84AF3V)

# %% [markdown]
# # Introduction
# The following set of code aims to investigate model creation and performance using neural networks for the [Brain Tumour MRI](https://www.kaggle.com/datasets/masoudnickparvar/brain-tumor-mri-dataset/data) dataset consisting of images divided into 4 main categories, glioma, meningioma, no tumour and pituatary, by considering the tanh activation function for a CNN (Convolution Neural Netowrk) model (explained [here](https://github.com/vivekp12/dst-group-project-2/blob/main/MarkM/ConvolutionLayers.ipynb)). We analyze how hyperparamater tuning (in this case learning rate, regularisation, weight initialisation and early stopping) affect model perforamnce by graphical represenations to show training and validation scores and losses. Keeping in mind that on downloading the folder of all the images, it is divided firstly into training and testing folders, one random image from the testing folder is chosen to test the model and evaluate its prediction power (for each hyperparameter tuning, this is done to analyze any relevant changes).
# <br>
# While hyperparameter tuning is an important part of this analysis, majority of the importance is given to create a distinction between 3 different activation functions and their effect on the prediction power of the respective models created for the Brain Tumour MRI dataset ([Swish](https://github.com/vivekp12/dst-group-project-2/blob/main/MarkM/Swish_research.ipynb) and [ReLU](https://github.com/vivekp12/dst-group-project-2/blob/main/VivekP/04-ReLUInvestigation.ipynb) being the other 2). The factors in common betweent the 3 projects created is the preprocessing of the data, checking for duplication and the optimizer used, which in this case is the Adam optimizer. The reason for selecting the Adam optimizer is for relatively faster convergence, the robustness allowing it to work well on a wide range of architectures and datasets and bias correction. Adam maintains adaptive learning rate for each parameters by considering two moving averages, the first moment estimate ($m_t$) and the second moment estimate ($v_t$), the former responsible for capturing the mean enabling necessary stabilizing updates, while the latter focuses on the varaince, thereby scaling parametrs. Both consist of inital bias correctors $\hat{m_t}$ and $\hat{v_t}$, which ensure stable estimates during hte initial steps of the training.

# %% [markdown]
# <br>

# %% [markdown]
# #1. Requirements
# Data augmentation which includes creating a cleaned folder of the training and testing images to have some sort of uniformity with respect to grey scaling of images or fixing dead pixels is performed. It is also observed that duplicates (if any) are checked and removed. This is an integral part for creating neural networks since data can be badly presented and unready for model creation which causes unnatural complexities during compiling, such as underperformance due to noise or even false prediction due to over or under fitting.

# %% [markdown]
# # 1.1 Data Augmentation

# %%
from pathlib import Path  # Import pathlib to work with paths
import kagglehub
import os  # Import os module for file operations
import hashlib
import numpy as np
from tqdm import tqdm
import cv2
import os
import imutils

# Download latest version
path = kagglehub.dataset_download("masoudnickparvar/brain-tumor-mri-dataset")

print("Path to dataset files:", path)

# Convert path to a Path object
path = Path(path)

PROJECT_DIR = path
LABELS = ['pituitary', 'notumor', 'meningioma', 'glioma']
def crop_img(img):
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    gray = cv2.GaussianBlur(gray, (3, 3), 0)
    thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
    thresh = cv2.erode(thresh, None, iterations=2)
    thresh = cv2.dilate(thresh, None, iterations=2)
    cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    c = max(cnts, key=cv2.contourArea)
    extLeft = tuple(c[c[:, :, 0].argmin()][0])
    extRight = tuple(c[c[:, :, 0].argmax()][0])
    extTop = tuple(c[c[:, :, 1].argmin()][0])
    extBot = tuple(c[c[:, :, 1].argmax()][0])
    ADD_PIXELS = 0
    new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()
    return new_img


# Convert 'path' to Path object (already done above)
train_dir = path / "Training"
test_dir = path / "Testing"

if __name__ == "__main__":
    training = train_dir
    testing = test_dir

    training_dir = os.listdir(training)
    testing_dir = os.listdir(testing)

    IMG_SIZE = 256

    for dir in training_dir:
        save_path = Path('cleaned/Training') / dir  # Using pathlib's '/' operator
        path = training / dir  # Using pathlib's '/' operator
        image_dir = os.listdir(path)

        for img in image_dir:
            image = cv2.imread(str(path / img))  # Convert Path to string for OpenCV
            new_img = crop_img(image)
            new_img = cv2.resize(new_img, (IMG_SIZE, IMG_SIZE))

            if not save_path.exists():
                save_path.mkdir(parents=True)

            cv2.imwrite(str(save_path / img), new_img)  # Convert Path to string for OpenCV

    for dir in testing_dir:
        save_path = Path('cleaned/Testing') / dir
        path = testing / dir
        image_dir = os.listdir(path)

        for img in image_dir:
            image = cv2.imread(str(path / img))
            new_img = crop_img(image)
            new_img = cv2.resize(new_img, (IMG_SIZE, IMG_SIZE))

            if not save_path.exists():
                save_path.mkdir(parents=True)

            cv2.imwrite(str(save_path / img), new_img)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/masoudnickparvar/brain-tumor-mri-dataset?dataset_version_number=1...
# 100%|██████████| 149M/149M [00:02<00:00, 56.2MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1

# %%
def compute_hash(file):
    hasher = hashlib.md5()
    with open(file, 'rb') as f:
        buf = f.read()
        hasher.update(buf)
    return hasher.hexdigest()


def list_files(hash_dict):
    for data_type in ['Training', 'Testing']:
        for label in LABELS:
            folder_path = os.path.join(PROJECT_DIR, 'data', 'raw', data_type, label)
            for root, dirs, files in os.walk(folder_path):
                for file in files:
                    if file.endswith(".jpg"):
                        file_path = os.path.join(root, file)
                        file_hash = compute_hash(file_path)
                        if file_hash in hash_dict:
                            hash_dict[file_hash].append(file_path)
                        else:
                            hash_dict[file_hash] = [file_path]


def remove_duplicates(hash_dict):
    duplicate_count = 0
    for hash_value, file_paths in hash_dict.items():
        if len(file_paths) > 1:
            for file_path in file_paths[1:]:
                print(f"Removing duplicate (hash : {hash_value}) : {file_path}")
                os.remove(file_path)
                duplicate_count += 1
    print(f"Number of duplicates : {duplicate_count}")


if __name__ == '__main__':
    hash_dict = {}
    list_files(hash_dict)
    remove_duplicates(hash_dict)
# Out:
# Number of duplicates : 0

# %% [markdown]
# <br>

# %% [markdown]
# # 1.2 Train and Test Splitting
#
#
# In this section we aim to use the function __ImageDataGenerator()__ as a means to preprocess the images in both the training and testing folders of the Brain MRI folder. This is done to create changes to images that promotes randomness and allows the model to generalise better on the available data and also on unseen data while testing.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
from pathlib import Path
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adamax
from sklearn.metrics import classification_report, confusion_matrix

# Define directories for training and testing images
train_dir = Path('cleaned/Training')
test_dir = Path('cleaned/Testing')

# Number of classes
LABELS = ['pituitary', 'notumor', 'meningioma', 'glioma']

# Image size and batch size
IMG_SIZE = 64  # Resize images to 64x64
BATCH_SIZE = 32

# Setup ImageDataGenerators for loading and preprocessing the images
train_datagen = ImageDataGenerator(
    rescale=1.0/255.0,  # Normalize pixel values to [0, 1]
    rotation_range=20,  # Random rotation
    width_shift_range=0.1,  # Horizontal shift
    height_shift_range=0.1,  # Vertical shift
    shear_range=0.2,  # Shear transformation
    zoom_range=0.2,  # Zoom in and out
    horizontal_flip=True,  # Flip horizontally
    fill_mode='nearest',  # Fill any missing pixels using the nearest pixel
    brightness_range=(0.5, 1.5),  # Randomly adjust brightness between 0.5 and 1.5 times the original
    channel_shift_range=20.0  # Randomly shift RGB channels (intensity)
)

test_datagen = ImageDataGenerator(rescale=1.0/255.0)  # Only rescale for test data

# Load images from directories using ImageDataGenerator
print('Training Data: ')

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),  # Resize images to 64x64
    batch_size=BATCH_SIZE,
    class_mode='categorical', # For multi-class classification
    shuffle=True
)


print('Testing Data: ')
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),  # Resize images to 64x64
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False  # Do not shuffle for test data
)
# Out:
# Training Data:
# Found 5712 images belonging to 4 classes.
# Testing Data:
# Found 1311 images belonging to 4 classes.

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# # 2. Model Training (Base Model)

# %% [markdown]
# # 2.1 Building and training the Model
# We use __Convlolution Neural Networks(CNN)__ with the __Tanh activation function__ on multiple input layers and __softmax__ function on the output layer for 4 classes. Model compiling takes place with the __Adam__ optimiser using the loss function as __categorical_crossentropy__ for a multi-class classificaton model consisting of mutliple output layers.
#
# <br>
#
# __Why the choice of__ __tanh__ __activation function ?__
# While there is no "best" activation function since each of them are used based on the data and the problem at hand, the choice of this activation function is merely for experimental purposes only. As a group each of us have chosen one based on our interests and consequenly an apt amount of research is performed.
# The tanh acitvation function used in neural networks given by:
# <div align="center"> $$ f(x) = \frac{e^x - e^{-x}}{e^x + e^{-x}} $$
# <br>
# <div align="left">
# is commonly used in Deep Neural Network (DNN) situtations to represent hidden layers. Also known as Hyperbolic Tangent Activation Function, it transforms input data into the values between -1 and 1 and accomodates the non-linearity between input and output data to learn more complex relationships. It is symmetric around the origin which in leighman's term means assigning negative values to negative data and positive to positive ones. This also means that the gradients are balanced when the weights are updated leading to faster convergence during training, but it is still susceptible to the vanishing gradient problem (gradients approaching zero when input is very large or very small). In backpropagation, each layer computes gradients based on the layer that follows it. If one layer has a very small gradient, it "passes" that small gradient backward, causing the earlier layers to receive even smaller gradients. This effect compounds in deep networks, particularly for networks with many layers.
# <br>
# The code and output below shows the usage of the tanh function along with accuracies obtained for both validation and training.

# %%
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam

# Build an optimized CNN model
model_base = Sequential([
    Conv2D(64, kernel_size=(3, 3), activation='tanh', input_shape=(64, 64, 3)),
    MaxPooling2D((2, 2)),

    Conv2D(128, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),

    Conv2D(256, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),

    Conv2D(512, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),

    Flatten(),
    Dense(512, activation='tanh'),
    Dense(128, activation='tanh'),

    Dense(4, activation='softmax')  # Output layer for 4 classes
])

model_base.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Train the model
history_base = model_base.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=100,  # Increased epochs to get better training results
    validation_data=test_generator,
    validation_steps=test_generator.samples // BATCH_SIZE
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 28s 116ms/step - accuracy: 0.3764 - loss: 1.4207 - val_accuracy: 0.5188 - val_loss: 1.3150
# Epoch 2/100
#   1/178 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6875 - loss: 0.8062
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6875 - loss: 0.8062 - val_accuracy: 1.0000 - val_loss: 0.1361
# Epoch 3/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 33s 97ms/step - accuracy: 0.6405 - loss: 0.8797 - val_accuracy: 0.6609 - val_loss: 0.8762
# Epoch 4/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 125us/step - accuracy: 0.6875 - loss: 0.7183 - val_accuracy: 1.0000 - val_loss: 0.1397
# Epoch 5/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 100ms/step - accuracy: 0.7211 - loss: 0.7045 - val_accuracy: 0.7156 - val_loss: 0.7680
# Epoch 6/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6562 - loss: 0.8016 - val_accuracy: 0.9355 - val_loss: 0.1724
# Epoch 7/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 95ms/step - accuracy: 0.7822 - loss: 0.5715 - val_accuracy: 0.7930 - val_loss: 0.5253
# Epoch 8/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - accuracy: 0.8438 - loss: 0.3860 - val_accuracy: 1.0000 - val_loss: 0.0850
# Epoch 9/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 99ms/step - accuracy: 0.8188 - loss: 0.5135 - val_accuracy: 0.8039 - val_loss: 0.5194
# Epoch 10/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7812 - loss: 0.5685 - val_accuracy: 0.8710 - val_loss: 0.4447
# Epoch 11/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 94ms/step - accuracy: 0.8068 - loss: 0.5172 - val_accuracy: 0.8086 - val_loss: 0.5541
# Epoch 12/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 105us/step - accuracy: 0.7812 - loss: 0.4187 - val_accuracy: 0.9355 - val_loss: 0.2142
# Epoch 13/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 99ms/step - accuracy: 0.8332 - loss: 0.4586 - val_accuracy: 0.8375 - val_loss: 0.4672
# Epoch 14/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8438 - loss: 0.4913 - val_accuracy: 1.0000 - val_loss: 0.0524
# Epoch 15/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.8470 - loss: 0.4363 - val_accuracy: 0.8086 - val_loss: 0.5449
# Epoch 16/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 137us/step - accuracy: 0.7812 - loss: 0.4471 - val_accuracy: 1.0000 - val_loss: 0.0333
# Epoch 17/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 104ms/step - accuracy: 0.8450 - loss: 0.4280 - val_accuracy: 0.7945 - val_loss: 0.5807
# Epoch 18/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7812 - loss: 0.4895 - val_accuracy: 0.9677 - val_loss: 0.0951
# Epoch 19/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 94ms/step - accuracy: 0.8542 - loss: 0.4066 - val_accuracy: 0.8391 - val_loss: 0.4344
# Epoch 20/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 160us/step - accuracy: 0.8438 - loss: 0.2956 - val_accuracy: 1.0000 - val_loss: 0.0484
# Epoch 21/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 93ms/step - accuracy: 0.8693 - loss: 0.3573 - val_accuracy: 0.8148 - val_loss: 0.5251
# Epoch 22/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - accuracy: 0.8125 - loss: 0.4877 - val_accuracy: 1.0000 - val_loss: 0.0337
# Epoch 23/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 92ms/step - accuracy: 0
# Epoch 100/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 144us/step - accuracy: 0.8750 - loss: 0.2528 - val_accuracy: 1.0000 - val_loss: 0.0092

# %% [markdown]
# <br>

# %% [markdown]
# # 2.2 Train and Test Accuracy
# The test and train accuracy and loss are calucalted to inference on the capability of the neural network model on the given set of images.

# %%
train_score = model_base.evaluate(train_generator)
test_score = model_base.evaluate(test_generator)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 92ms/step - accuracy: 0.9101 - loss: 0.2418
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8113 - loss: 0.5161
# Train Loss:  0.2471482902765274
# Train Accuracy:  0.9075630307197571
# --------------------
# --------------------
# Test Loss:  0.3586418926715851
# Test Accuracy:  0.8642258048057556

# %% [markdown]
# <br>

# %% [markdown]
# # 2.3 Plotting Training History

# %%
plt.plot(history_base.history['accuracy'], label='Training Accuracy')
plt.plot(history_base.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(history_base.history['loss'], label='Training Loss')
plt.plot(history_base.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# The graph here of epochs against accuracy and loss tells for both training and validation data tells us how the model progresses towards improving it's accuracy and reducing its loss with each epoch. It is generally seen that the training accuracy improves are the first few epochs with reaching its high around the 50$^{th}$ epoch. A similar trend could be inferred about the training loss as well. This may imply a discussion on whether 100 epochs could be considered too many, and hence further in the notebook this concept will be tended to. The validation accuracy and loss follows a very peculiar trend of constantly oscillating between values, while still showcasing and overall upward and downward trend for the training and loss scores respectively. The question is why do we see this osccilatory behaviour? While the answer is not obvious, it could be due to multiple underlying reasons, a few of which are excessively high learning rate, insufficient regularization, or noisy training data causing an unstable training process.
# The base model in this case tells us that from [Section 2.2](#scrollTo=dQ9sN6o4fVEc) and [Section 6](#scrollTo=ztNRGf3QSsSl) the model performs on the training (unseen) data by getting good training accuracy for the complete test data and by predicting the image with a high accuracy from the testing folder. Graphically this may not seem the case as there still could be room for improvement by fixing the problems of oscillating validation scores, mentioned before.

# %%
model_base.save('model_base.keras')

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# # 3. Paramter Tuning

# %% [markdown]
# # 3.1 Regularisation (Batch Normalisation and Dropout)
# Regularisation is introduced through __BatchNormalisation()__ and __Dropout=0.5__ to stabilize training and balance the trade-off between keeping enough neurons to learn meaningful patterns and enforcing regularization to prevent overfitting.
# <br>
# __Dropout__:
# Overfitting is caused by the network learning patterns in the training data. To recognize these patterns a network will often rely on very a specific combination of weights, which tend to be fragile where removing one of these weights will crumble the combination. Hence why we use dropout.
# To break up these combinations, we randomly drop out some fraction of a layer's input units (neurons or nodes) every step of training, making it much harder for the network to learn those false patterns in the training data. The dropout probability for the nodes is considered as $p$. For instance, if the hidden layers have 2000 neurons (nodes) and a dropout is applied with probability = 0.5, then 1000 neurons would be randomly dropped in every batch. It has to search for broad, general patterns, whose weight patterns tend to be more robust.
# <br>
# __BatchNormalisation:__
# A batch normalization layer looks at each batch as it comes in, first normalizing the outputs of the previous hidden layer with its own moving average mean and moving average standard deviation before processing them as inputs for the next hidden layer, and then also putting the data on a new scale with two trainable rescaling parameters beta ($\beta$) and gamma ($\gamma$). These parameters are present in each batchnorm layer, which means multiple hidden and batchnorm layers imply the same amount of parameters both trainable and fixed.
# Most often, batchnorm is added as an aid to the optimization process (though it can sometimes also help prediction performance). Models with batchnorm tend to need fewer epochs to complete training. Moreover, batchnorm can also fix various problems that can cause the training to get "stuck".

# %% [markdown]
# # 3.1.1 Building and Training the Model

# %%
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam

#
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.7288 - loss: 0.7762
# Train Loss:  0.49068790674209595
# Train Accuracy:  0.8273809552192688
# --------------------
# --------------------
# Test Loss:  0.543732225894928
# Test Accuracy:  0.8154081106185913

# %% [markdown]
# <br>

# %% [markdown]
# # 3.1.3 Plotting Training History

# %%
plt.plot(history_reg.history['accuracy'], label='Training Accuracy')
plt.plot(history_reg.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(history_reg.history['loss'], label='Training Loss')
plt.plot(history_reg.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
 model_reg.save('model_reg.keras')

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# # 3.2 Regularisation (Early Stopping)
# 100 epochs may seem like overkill, so using early stopping while monitoring validation loss avoids all 100 epochs to run, preventing overfitting.

# %% [markdown]
# # 3.2.1 Building and Training the Model

# %%
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam

# Build an optimized CNN model
model_early = Sequential([
    Conv2D(64, kernel_size=(3, 3), activation='tanh', input_shape=(64, 64, 3)),
    MaxPooling2D((2, 2)),

    Conv2D(128, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),

    Conv2D(256, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),

    Conv2D(512, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),

    Flatten(),
    Dense(512, activation='tanh'),
    Dense(128, activation='tanh'),

    Dense(4, activation='softmax')  # Output layer for 4 classes
])

model_early.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow import keras
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',  # Metric to monitor
    patience=20,  # Number of epochs with no improvement after which training will be stopped
    verbose=1,  # Print a message when training is stopped
    restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored metric
)

# %%
history_early = model_early.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=100,  # Increased epochs to get better training results
    validation_data=test_generator,
    validation_steps=test_generator.samples // BATCH_SIZE
    ,callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 23s 112ms/step - accuracy: 0.3795 - loss: 1.4566 - val_accuracy: 0.6555 - val_loss: 0.9141
# Epoch 2/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6875 - loss: 0.7510 - val_accuracy: 0.7742 - val_loss: 0.6706
# Epoch 3/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 92ms/step - accuracy: 0.6225 - loss: 0.8999 - val_accuracy: 0.6281 - val_loss: 0.8822
# Epoch 4/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - accuracy: 0.7500 - loss: 0.7173 - val_accuracy: 0.9355 - val_loss: 0.4568
# Epoch 5/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.7105 - loss: 0.7096 - val_accuracy: 0.7609 - val_loss: 0.6425
# Epoch 6/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7188 - loss: 0.6724 - val_accuracy: 1.0000 - val_loss: 0.0877
# Epoch 7/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 92ms/step - accuracy: 0.7772 - loss: 0.5950 - val_accuracy: 0.7664 - val_loss: 0.6484
# Epoch 8/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 128us/step - accuracy: 0.7812 - loss: 0.6718 - val_accuracy: 0.9677 - val_loss: 0.1130
# Epoch 9/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 96ms/step - accuracy: 0.7961 - loss: 0.5367 - val_accuracy: 0.7859 - val_loss: 0.5772
# Epoch 10/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8438 - loss: 0.3619 - val_accuracy: 1.0000 - val_loss: 0.0206
# Epoch 11/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 92ms/step - accuracy: 0.8273 - loss: 0.4789 - val_accuracy: 0.7703 - val_loss: 0.5898
# Epoch 12/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 114us/step - accuracy: 0.7188 - loss: 0.7492 - val_accuracy: 1.0000 - val_loss: 0.0385
# Epoch 13/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 93ms/step - accuracy: 0.8129 - loss: 0.4871 - val_accuracy: 0.7664 - val_loss: 0.6701
# Epoch 14/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.8750 - loss: 0.3891 - val_accuracy: 1.0000 - val_loss: 0.0645
# Epoch 15/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 99ms/step - accuracy: 0.8424 - loss: 0.4379 - val_accuracy: 0.8281 - val_loss: 0.5070
# Epoch 16/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 115us/step - accuracy: 0.8125 - loss: 0.3804 - val_accuracy: 1.0000 - val_loss: 0.0291
# Epoch 17/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 92ms/step - accuracy: 0.8588 - loss: 0.3720 - val_accuracy: 0.8297 - val_loss: 0.4926
# Epoch 18/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 131us/step - accuracy: 0.9375 - loss: 0.2443 - val_accuracy: 1.0000 - val_loss: 0.0738
# Epoch 19/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 94ms/step - accuracy: 0.8629 - loss: 0.3788 - val_accuracy: 0.8547 - val_loss: 0.3941
# Epoch 20/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9375 - loss: 0.3083 - val_accuracy: 1.0000 - val_loss: 0.0636
# Epoch 21/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 92ms/step - accuracy: 0.8525 - loss: 0.4104 - val_accuracy: 0.8500 - val_loss: 0.4165
# Epoch 22/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 134us/step - accuracy: 0.7812 - loss: 0.6016 - val_accuracy: 1.0000 - val_loss: 0.0698
# Epoch 23/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 97ms/step - accuracy: 0.8703 - loss: 0.3495 - val_accuracy: 0.8406 - val_loss: 0.4577
# Epoch 24/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - accuracy: 0.9375 - loss: 0.2519 - val_accuracy: 1.0000 - val_loss: 0.0290
# Epoch 25/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.8886 - loss: 0.3260 - val_accuracy: 0.8523 - val_loss: 0.4308
# Epoch 26/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7812 - loss: 0.4996 - val_accuracy: 0.8710 - val_loss: 0.3550
# Epoch 27/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 98ms/step - accuracy: 0.8861 - loss: 0.3256 - val_accuracy: 0.8820 - val_loss: 0.3309
# Epoch 28/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 123us/step - accuracy: 0.8750 - loss: 0.3279 - val_accuracy: 0.9677 - val_loss: 0.1376
# Epoch 29/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - accuracy: 0.8811 - loss: 0.3150 - val_accuracy: 0.8219 - val_loss: 0.4809
# Epoch 30/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 174us/step - accuracy: 0.9062 - loss: 0.2856 - val_accuracy: 1.0000 - val_loss: 0.0077
# Epoch 31/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 97ms/step - accuracy: 0.8774 - loss: 0.3370 - val_accuracy: 0.8500 - val_loss: 0.4193
# Epoch 32/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 218us/step - accuracy: 0.9062 - loss: 0.2648 - val_accuracy: 1.0000 - val_loss: 0.0075
# Epoch 33/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 92ms/step - accuracy: 0.8918 - loss: 0.3159 - val_accuracy: 0.8633 - val_loss: 0.3519
# Epoch 34/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 124us/step - accuracy: 0.9375 - loss: 0.2009 - val_accuracy: 0.9677 - val_loss: 0.0575
# Epoch 35/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 92ms/step - accuracy: 0.8867 - loss: 0.3125 - val_accuracy: 0.9102 - val_loss: 0.2673
# Epoch 36/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8750 - loss: 0.2525 - val_accuracy: 0.9677 - val_loss: 0.1265
# Epoch 37/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 93ms/step - accuracy: 0.8784 - loss: 0.3181 - val_accuracy: 0.8523 - val_loss: 0.4274
# Epoch 38/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.8750 - loss: 0.4091 - val_accuracy: 1.0000 - val_loss: 0.0236
# Epoch 39/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 92ms/step - accuracy: 0.8929 - loss: 0.2911 - val_accuracy: 0.8641 - val_loss: 0.3738
# Epoch 40/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 125us/step - accuracy: 0.8750 - loss: 0.2206 - val_accuracy: 1.0000 - val_loss: 0.0339
# Epoch 41/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 96ms/step - accuracy: 0.8836 - loss: 0.3308 - val_accuracy: 0.8766 - val_loss: 0.3293
# Epoch 42/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 120us/step - accuracy: 0.8750 - loss: 0.3133 - val_accuracy: 0.9677 - val_loss: 0.1349
# Epoch 43/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 92ms/step - accuracy: 0.8975 - loss: 0.2837 - val_accuracy: 0.8828 - val_loss: 0.3065
# Epoch 44/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 102us/step - accuracy: 0.7812 - loss: 0.4427 - val_accuracy: 1.0000 - val_loss: 0.0184
# Epoch 45/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.9015 - loss: 0.2655 - val_accuracy: 0.8750 - val_loss: 0.3292
# Epoch 46/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8750 - loss: 0.4203 - val_accuracy: 0.9677 - val_loss: 0.1116
# Epoch 47/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 92ms/step - accuracy: 0.8923 - loss: 0.2999 - val_accuracy: 0.8664 - val_loss: 0.3526
# Epoch 48/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - accuracy: 0.8125 - loss: 0.4773 - val_accuracy: 1.0000 - val_loss: 0.0336
# Epoch 49/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 95ms/step - accuracy: 0.8817 - loss: 0.3131 - val_accuracy: 0.9078 - val_loss: 0.2613
# Epoch 50/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 113us/step - accuracy: 0.8438 - loss: 0.2368 - val_accuracy: 0.9677 - val_loss: 0.0713
# Epoch 51/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 95ms/step - accuracy: 0.9063 - loss: 0.2626 - val_accuracy: 0.8719 - val_loss: 0.3248
# Epoch 52/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 172us/step - accuracy: 0.8438 - loss: 0.2922 - val_accuracy: 1.0000 - val_loss: 0.0221
# Epoch 52: early stopping
# Restoring model weights from the end of the best epoch: 32.

# %% [markdown]
# <br>

# %% [markdown]
# # 3.2.2 Train and Test Accuracy

# %%
train_score = model_early.evaluate(train_generator)
test_score = model_early.evaluate(test_generator)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 92ms/step - accuracy: 0.8816 - loss: 0.3342
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.7968 - loss: 0.5628
# Train Loss:  0.3315470814704895
# Train Accuracy:  0.8814775943756104
# --------------------
# --------------------
# Test Loss:  0.3960232734680176
# Test Accuracy:  0.8611747026443481

# %% [markdown]
# <br>

# %% [markdown]
# # 3.2.3 Plotting Training History

# %%
plt.plot(history_early.history['accuracy'], label='Training Accuracy')
plt.plot(history_early.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(history_early.history['loss'], label='Training Loss')
plt.plot(history_early.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# <br>

# %%
model_early.save('model_early.keras')

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# # 3.3 Learning Rate Scheduler
# We aim to reduce learning rate while monitoring validation loss in order to get optimal training and validation scores. A reduced learning rate in theory optimizes performance by forcing the optimizer to make smaller adjustments, fine-tuning parameters for better performance. This inturn stabilizes training and overall performance. Here we have only considered the [ReduceLROnPlateau](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/ReduceLROnPlateau) scheduler into consideration, while some other schedulers include Step Decay, Exponential Decay, Cosine Annealing, etc.

# %% [markdown]
# # 3.3.1 Building and Training the Model

# %%
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam

# Build an optimized CNN model
model_reduce_lr = Sequential([
    Conv2D(64, kernel_size=(3, 3), activation='tanh', input_shape=(64, 64, 3)),
    MaxPooling2D((2, 2)),

    Conv2D(128, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),

    Conv2D(256, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),

    Conv2D(512, kernel_size=(3, 3), activation='tanh'),
    MaxPooling2D((2, 2)),

    Flatten(),
    Dense(512, activation='tanh'),
    Dense(128, activation='tanh'),

    Dense(4, activation='softmax')  # Output layer for 4 classes
])

model_reduce_lr.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow import keras
reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',  # Metric to monitor
    factor=0.1,  # Factor by which the learning rate will be reduced
    patience=10,  # Number of epochs with no improvement after which learning rate will be reduced
    verbose=1,  # Print messages when learning rate is reduced
    min_delta=0.0001, # Minimum change in the monitored quantity to qualify as an improvement.
    cooldown=0, # Number of epochs to wait before resuming normal operation after lr has been reduced.
    min_lr=0,  # Lower bound on the learning rate.
)

# %%
history_reduce_lr = model_reduce_lr.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=100,  # Increased epochs to get better training results
    validation_data=test_generator,
    validation_steps=test_generator.samples // BATCH_SIZE
    ,callbacks=[reduce_lr])
# Out:
# Epoch 1/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.3959 - loss: 1.3905 - val_accuracy: 0.5867 - val_loss: 1.0393 - learning_rate: 0.0010
# Epoch 2/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3750 - loss: 1.2660 - val_accuracy: 0.9677 - val_loss: 0.2676 - learning_rate: 0.0010
# Epoch 3/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 95ms/step - accuracy: 0.6617 - loss: 0.8422 - val_accuracy: 0.6672 - val_loss: 0.9170 - learning_rate: 0.0010
# Epoch 4/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.6875 - loss: 0.7459 - val_accuracy: 0.9355 - val_loss: 0.1583 - learning_rate: 0.0010
# Epoch 5/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 93ms/step - accuracy: 0.7510 - loss: 0.6569 - val_accuracy: 0.7922 - val_loss: 0.5489 - learning_rate: 0.0010
# Epoch 6/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - accuracy: 0.8125 - loss: 0.4486 - val_accuracy: 0.8065 - val_loss: 0.5135 - learning_rate: 0.0010
# Epoch 7/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 92ms/step - accuracy: 0.7749 - loss: 0.6032 - val_accuracy: 0.7828 - val_loss: 0.5789 - learning_rate: 0.0010
# Epoch 8/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step - accuracy: 0.7500 - loss: 0.5402 - val_accuracy: 0.9677 - val_loss: 0.1563 - learning_rate: 0.0010
# Epoch 9/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 98ms/step - accuracy: 0.7985 - loss: 0.5277 - val_accuracy: 0.8250 - val_loss: 0.4604 - learning_rate: 0.0010
# Epoch 10/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - accuracy: 0.8438 - loss: 0.5546 - val_accuracy: 1.0000 - val_loss: 0.1198 - learning_rate: 0.0010
# Epoch 11/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 92ms/step - accuracy: 0.8292 - loss: 0.4765 - val_accuracy: 0.8055 - val_loss: 0.5160 - learning_rate: 0.0010
# Epoch 12/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 138us/step - accuracy: 0.8438 - loss: 0.4087 - val_accuracy: 0.9677 - val_loss: 0.1252 - learning_rate: 0.0010
# Epoch 13/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - accuracy: 0.8480 - loss: 0.4110 - val_accuracy: 0.8305 - val_loss: 0.4390 - learning_rate: 0.0010
# Epoch 14/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 122us/step - accuracy: 0.9375 - loss: 0.3307 - val_accuracy: 1.0000 - val_loss: 0.0563 - learning_rate: 0.0010
# Epoch 15/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 93ms/step - accuracy: 0.8477 - loss: 0.4129 - val_accuracy: 0.8570 - val_loss: 0.3875 - learning_rate: 0.0010
# Epoch 16/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9375 - loss: 0.2782 - val_accuracy: 0.9677 - val_loss: 0.1051 - learning_rate: 0.0010
# Epoch 17/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 91ms/step - accuracy: 0.8582 - loss: 0.4101 - val_accuracy: 0.8664 - val_loss: 0.3835 - learning_rate: 0.0010
# Epoch 18/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 118us/step - accuracy: 0.8438 - loss: 0.4115 - val_accuracy: 0.9677 - val_loss: 0.1237 - learning_rate: 0.0010
# Epoch 19/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 94ms/step - accuracy: 0.8549 - loss: 0.3848 - val_accuracy: 0.8664 - val_loss: 0.3658 - learning_rate: 0.0010
# Epoch 20/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7500 - loss: 0.4521 - val_accuracy: 1.0000 - val_loss: 0.0706 - learning_rate: 0.0010
# Epoch 21/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 91ms/step - accuracy: 0.8778 - loss: 0.3427 - val_accuracy: 0.8523 - val_loss: 0.3777 - learning_rate: 0.0010
# Epoch 22/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 111us/step - accuracy: 0.8125 - loss: 0.6411 - val_accuracy: 1.0000 - val_loss: 0.0246 - learning_rate: 0.0010
# Epoch 23/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━
# Epoch 78/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 133us/step - accuracy: 0.9375 - loss: 0.1569 - val_accuracy: 1.0000 - val_loss: 0.0098 - learning_rate: 1.0000e-05
# Epoch 79/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - accuracy: 0.9540 - loss: 0.1322 - val_accuracy: 0.9336 - val_loss: 0.2039 - learning_rate: 1.0000e-05
# Epoch 80/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - accuracy: 0.9688 - loss: 0.1429 - val_accuracy: 1.0000 - val_loss: 0.0101 - learning_rate: 1.0000e-05
# Epoch 81/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 92ms/step - accuracy: 0.9516 - loss: 0.1326 - val_accuracy: 0.9328 - val_loss: 0.2141 - learning_rate: 1.0000e-05
# Epoch 82/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 134us/step - accuracy: 0.9688 - loss: 0.1971 - val_accuracy: 1.0000 - val_loss: 0.0102 - learning_rate: 1.0000e-05
# Epoch 83/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 97ms/step - accuracy: 0.9509 - loss: 0.1383 - val_accuracy: 0.9359 - val_loss: 0.2093 - learning_rate: 1.0000e-05
# Epoch 84/100
#   1/178 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9688 - loss: 0.1144
# Epoch 84: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9688 - loss: 0.1144 - val_accuracy: 1.0000 - val_loss: 0.0101 - learning_rate: 1.0000e-05
# Epoch 85/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - accuracy: 0.9556 - loss: 0.1354 - val_accuracy: 0.9359 - val_loss: 0.2085 - learning_rate: 1.0000e-06
# Epoch 86/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 125us/step - accuracy: 0.9688 - loss: 0.0890 - val_accuracy: 1.0000 - val_loss: 0.0102 - learning_rate: 1.0000e-06
# Epoch 87/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 97ms/step - accuracy: 0.9552 - loss: 0.1325 - val_accuracy: 0.9336 - val_loss: 0.2098 - learning_rate: 1.0000e-06
# Epoch 88/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 113us/step - accuracy: 0.9062 - loss: 0.1459 - val_accuracy: 1.0000 - val_loss: 0.0103 - learning_rate: 1.0000e-06
# Epoch 89/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 92ms/step - accuracy: 0.9514 - loss: 0.1340 - val_accuracy: 0.9352 - val_loss: 0.2091 - learning_rate: 1.0000e-06
# Epoch 90/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.9375 - loss: 0.1472 - val_accuracy: 1.0000 - val_loss: 0.0103 - learning_rate: 1.0000e-06
# Epoch 91/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 95ms/step - accuracy: 0.9509 - loss: 0.1324 - val_accuracy: 0.9359 - val_loss: 0.2078 - learning_rate: 1.0000e-06
# Epoch 92/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9688 - loss: 0.1379 - val_accuracy: 1.0000 - val_loss: 0.0103 - learning_rate: 1.0000e-06
# Epoch 93/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 92ms/step - accuracy: 0.9559 - loss: 0.1211 - val_accuracy: 0.9352 - val_loss: 0.2080 - learning_rate: 1.0000e-06
# Epoch 94/100
#   1/178 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8438 - loss: 0.3390
# Epoch 94: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 177us/step - accuracy: 0.8438 - loss: 0.3390 - val_accuracy: 1.0000 - val_loss: 0.0103 - learning_rate: 1.0000e-06
# Epoch 95/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 93ms/step - accuracy: 0.9567 - loss: 0.1227 - val_accuracy: 0.9352 - val_loss: 0.2079 - learning_rate: 1.0000e-07
# Epoch 96/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - accuracy: 0.8750 - loss: 0.2113 - val_accuracy: 1.0000 - val_loss: 0.0103 - learning_rate: 1.0000e-07
# Epoch 97/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 97ms/step - accuracy: 0.9576 - loss: 0.1283 - val_accuracy: 0.9352 - val_loss: 0.2079 - learning_rate: 1.0000e-07
# Epoch 98/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 140us/step - accuracy: 0.9375 - loss: 0.1455 - val_accuracy: 1.0000 - val_loss: 0.0103 - learning_rate: 1.0000e-07
# Epoch 99/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 98ms/step - accuracy: 0.9578 - loss: 0.1285 - val_accuracy: 0.9352 - val_loss: 0.2076 - learning_rate: 1.0000e-07
# Epoch 100/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 0.8750 - loss: 0.2267 - val_accuracy: 1.0000 - val_loss: 0.0103 - learning_rate: 1.0000e-07

# %% [markdown]
# <br>

# %% [markdown]
# # 3.3.2 Train and Test Accuracy

# %%
train_score = model_reduce_lr.evaluate(train_generator)
test_score = model_reduce_lr.evaluate(test_generator)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 88ms/step - accuracy: 0.9521 - loss: 0.1359
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9105 - loss: 0.2938
# Train Loss:  0.1348697543144226
# Train Accuracy:  0.9527310729026794
# --------------------
# --------------------
# Test Loss:  0.20297753810882568
# Test Accuracy:  0.936689555644989

# %% [markdown]
# <br>

# %% [markdown]
# # 3.3.3 Plotting Training History

# %%
plt.plot(history_reduce_lr.history['accuracy'], label='Training Accuracy')
plt.plot(history_reduce_lr.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(history_reduce_lr.history['loss'], label='Training Loss')
plt.plot(history_reduce_lr.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# <br>

# %%
model_reduce_lr.save('model_reduce_lr.keras')

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# # 3.4 Weight Initialisation
# Here we use Xavier Initialisation also known as __Glorot Initialisation__, which is a weight initialisation method ([more info on weight initialisation here]() that ensures constant variance of inputs and outputs of each layer. It is mostly used in conjuntion with __tanh__ activation function to tackle the vanishing or exploding gradient problem common in deep networks. The function in python is [GlorotUniform]((https://www.tensorflow.org/api_docs/python/tf/keras/initializers/GlorotUniform) and it draws samples from a uniform distribution within $ [-limit, limit] $, where $$ limit = \sqrt{\frac{6}{fan_{in} + fan_{out}}} $$
# <br>
# $ fan_{in} $ is the number of input units in the weight tensor and $ fan_{out} $ is the number of output units.

# %% [markdown]
# # 3.4.1 Building and Training the Model

# %%
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import GlorotUniform

# Build an optimized CNN model
model_xavier = Sequential([
    Conv2D(64, kernel_size=(3, 3), activation='tanh', input_shape=(64, 64, 3), kernel_initializer=GlorotUniform()),
    MaxPooling2D((2, 2)),

    Conv2D(128, kernel_size=(3, 3), activation='tanh', kernel_initializer=GlorotUniform()),
    MaxPooling2D((2, 2)),

    Conv2D(256, kernel_size=(3, 3), activation='tanh', kernel_initializer=GlorotUniform()),
    MaxPooling2D((2, 2)),

    Conv2D(512, kernel_size=(3, 3), activation='tanh', kernel_initializer=GlorotUniform()),
    MaxPooling2D((2, 2)),

    Flatten(),
    Dense(512, activation='tanh', kernel_initializer=GlorotUniform()),
    Dense(128, activation='tanh', kernel_initializer=GlorotUniform()),

    Dense(4, activation='softmax')  # Output layer for 4 classes
])

model_xavier.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history_xavier = model_xavier.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=100,  # Increased epochs to get better training results
    validation_data=test_generator,
    validation_steps=test_generator.samples // BATCH_SIZE
)
# Out:
# Epoch 1/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.2961 - loss: 1.7371 - val_accuracy: 0.4719 - val_loss: 1.2212
# Epoch 2/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4375 - loss: 1.2075 - val_accuracy: 0.6129 - val_loss: 1.1074
# Epoch 3/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - accuracy: 0.4743 - loss: 1.1691 - val_accuracy: 0.6266 - val_loss: 0.8999
# Epoch 4/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6250 - loss: 0.8948 - val_accuracy: 0.9355 - val_loss: 0.5947
# Epoch 5/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 93ms/step - accuracy: 0.6308 - loss: 0.9059 - val_accuracy: 0.7109 - val_loss: 0.7433
# Epoch 6/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.7188 - loss: 0.6989 - val_accuracy: 0.8065 - val_loss: 0.5717
# Epoch 7/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - accuracy: 0.7080 - loss: 0.7311 - val_accuracy: 0.6469 - val_loss: 0.9060
# Epoch 8/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8438 - loss: 0.5687 - val_accuracy: 0.9677 - val_loss: 0.2089
# Epoch 9/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - accuracy: 0.7626 - loss: 0.6220 - val_accuracy: 0.7711 - val_loss: 0.6009
# Epoch 10/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 124us/step - accuracy: 0.6562 - loss: 0.7989 - val_accuracy: 1.0000 - val_loss: 0.1012
# Epoch 11/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 92ms/step - accuracy: 0.7839 - loss: 0.5575 - val_accuracy: 0.7937 - val_loss: 0.5915
# Epoch 12/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - accuracy: 0.8125 - loss: 0.4603 - val_accuracy: 0.9355 - val_loss: 0.2071
# Epoch 13/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 94ms/step - accuracy: 0.8033 - loss: 0.5157 - val_accuracy: 0.8141 - val_loss: 0.5555
# Epoch 14/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - accuracy: 0.7812 - loss: 0.5987 - val_accuracy: 0.9677 - val_loss: 0.1682
# Epoch 15/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - accuracy: 0.8299 - loss: 0.4579 - val_accuracy: 0.7977 - val_loss: 0.5468
# Epoch 16/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 123us/step - accuracy: 0.8125 - loss: 0.6210 - val_accuracy: 0.9677 - val_loss: 0.1685
# Epoch 17/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - accuracy: 0.8392 - loss: 0.4349 - val_accuracy: 0.8398 - val_loss: 0.4496
# Epoch 18/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 229us/step - accuracy: 0.8750 - loss: 0.3593 - val_accuracy: 0.9677 - val_loss: 0.1585
# Epoch 19/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 95ms/step - accuracy: 0.8532 - loss: 0.4083 - val_accuracy: 0.7852 - val_loss: 0.5503
# Epoch 20/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 114us/step - accuracy: 0.8438 - loss: 0.4983 - val_accuracy: 1.0000 - val_loss: 0.0449
# Epoch 21/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.8504 - loss: 0.4201 - val_accuracy: 0.8109 - val_loss: 0.4953
# Epoch 22/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s
# Epoch 100/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 159us/step - accuracy: 0.9062 - loss: 0.2576 - val_accuracy: 1.0000 - val_loss: 0.0182

# %% [markdown]
# <br>

# %% [markdown]
# # 3.4.2 Train and Test Accuracy

# %%
train_score = model_xavier.evaluate(train_generator)
test_score = model_xavier.evaluate(test_generator)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 86ms/step - accuracy: 0.9109 - loss: 0.2421
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8540 - loss: 0.3674
# Train Loss:  0.248553067445755
# Train Accuracy:  0.9093137383460999
# --------------------
# --------------------
# Test Loss:  0.28237947821617126
# Test Accuracy:  0.8901602029800415

# %% [markdown]
# <br>

# %% [markdown]
# # 3.4.3 Plotting Training History

# %%
plt.plot(history_xavier.history['accuracy'], label='Training Accuracy')
plt.plot(history_xavier.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(history_xavier.history['loss'], label='Training Loss')
plt.plot(history_xavier.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# # 3.5 Final Model

# %%
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import GlorotUniform

# Build an optimized CNN model
model_all = Sequential([
    Conv2D(64, kernel_size=(3, 3), activation='tanh', input_shape=(64, 64, 3), kernel_initializer=GlorotUniform()),
    MaxPooling2D((2, 2)),
    BatchNormalization(),

    Conv2D(128, kernel_size=(3, 3), activation='tanh', kernel_initializer=GlorotUniform()),
    MaxPooling2D((2, 2)),
    BatchNormalization(),

    Conv2D(256, kernel_size=(3, 3), activation='tanh', kernel_initializer=GlorotUniform()),
    MaxPooling2D((2, 2)),
    BatchNormalization(),

    Conv2D(512, kernel_size=(3, 3), activation='tanh', kernel_initializer=GlorotUniform()),
    MaxPooling2D((2, 2)),
    BatchNormalization(),

    Flatten(),
    Dense(512, activation='tanh', kernel_initializer=GlorotUniform()),
    Dropout(0.5),
    Dense(128, activation='tanh', kernel_initializer=GlorotUniform()),
    Dropout(0.5),

    Dense(4, activation='softmax')  # Output layer for 4 classes
])

model_all.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow import keras
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=20,
    verbose=1,
    restore_best_weights=True
)

reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=10,
    verbose=1,
    min_delta=0.0001,
    cooldown=0,
    min_lr=0,
)

# %%
history_all = model_all.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=100,  # Increased epochs to get better training results
    validation_data=test_generator,
    validation_steps=test_generator.samples // BATCH_SIZE
    ,callbacks=[reduce_lr])
# Out:
# Epoch 1/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 28s 118ms/step - accuracy: 0.3367 - loss: 1.7567 - val_accuracy: 0.4703 - val_loss: 1.2619 - learning_rate: 0.0010
# Epoch 2/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.5938 - loss: 1.0646 - val_accuracy: 0.0000e+00 - val_loss: 1.8078 - learning_rate: 0.0010
# Epoch 3/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 30s 92ms/step - accuracy: 0.4083 - loss: 1.4061 - val_accuracy: 0.4789 - val_loss: 1.1365 - learning_rate: 0.0010
# Epoch 4/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 105us/step - accuracy: 0.3438 - loss: 1.5480 - val_accuracy: 0.0000e+00 - val_loss: 1.4406 - learning_rate: 0.0010
# Epoch 5/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 95ms/step - accuracy: 0.4816 - loss: 1.2165 - val_accuracy: 0.4961 - val_loss: 1.0857 - learning_rate: 0.0010
# Epoch 6/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 141us/step - accuracy: 0.6562 - loss: 0.9671 - val_accuracy: 0.2581 - val_loss: 1.4280 - learning_rate: 0.0010
# Epoch 7/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 94ms/step - accuracy: 0.5383 - loss: 1.0732 - val_accuracy: 0.6016 - val_loss: 1.0311 - learning_rate: 0.0010
# Epoch 8/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 128us/step - accuracy: 0.6562 - loss: 0.8673 - val_accuracy: 0.9677 - val_loss: 0.3114 - learning_rate: 0.0010
# Epoch 9/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 98ms/step - accuracy: 0.6484 - loss: 0.8536 - val_accuracy: 0.6531 - val_loss: 0.9409 - learning_rate: 0.0010
# Epoch 10/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 128us/step - accuracy: 0.6875 - loss: 0.9242 - val_accuracy: 0.8387 - val_loss: 0.5213 - learning_rate: 0.0010
# Epoch 11/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 93ms/step - accuracy: 0.7103 - loss: 0.7578 - val_accuracy: 0.6961 - val_loss: 0.8376 - learning_rate: 0.0010
# Epoch 12/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 115us/step - accuracy: 0.7500 - loss: 0.7140 - val_accuracy: 0.9677 - val_loss: 0.1218 - learning_rate: 0.0010
# Epoch 13/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 96ms/step - accuracy: 0.7415 - loss: 0.6546 - val_accuracy: 0.7477 - val_loss: 0.6844 - learning_rate: 0.0010
# Epoch 14/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 129us/step - accuracy: 0.8438 - loss: 0.4542 - val_accuracy: 0.8710 - val_loss: 0.3358 - learning_rate: 0.0010
# Epoch 15/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 92ms/step - accuracy: 0.7830 - loss: 0.5944 - val_accuracy: 0.5398 - val_loss: 1.4831 - learning_rate: 0.0010
# Epoch 16/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s
# Epoch 42/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 119us/step - accuracy: 0.9062 - loss: 0.2661 - val_accuracy: 0.9677 - val_loss: 0.0901 - learning_rate: 1.0000e-04
# Epoch 43/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 92ms/step - accuracy: 0.8730 - loss: 0.3576 - val_accuracy: 0.8477 - val_loss: 0.4510 - learning_rate: 1.0000e-04
# Epoch 44/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 121us/step - accuracy: 0.8438 - loss: 0.3763 - val_accuracy: 1.0000 - val_loss: 0.0317 - learning_rate: 1.0000e-04
# Epoch 45/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 98ms/step - accuracy: 0.8821 - loss: 0.3499 - val_accuracy: 0.8109 - val_loss: 0.5673 - learning_rate: 1.0000e-04
# Epoch 46/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.9062 - loss: 0.3706 - val_accuracy: 0.9677 - val_loss: 0.0641 - learning_rate: 1.0000e-04
# Epoch 47/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 93ms/step - accuracy: 0.8779 - loss: 0.3534 - val_accuracy: 0.8086 - val_loss: 0.5603 - learning_rate: 1.0000e-04
# Epoch 48/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 194us/step - accuracy: 0.8438 - loss: 0.4131 - val_accuracy: 1.0000 - val_loss: 0.0283 - learning_rate: 1.0000e-04
# Epoch 49/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 103ms/step - accuracy: 0.8786 - loss: 0.3399 - val_accuracy: 0.7844 - val_loss: 0.6721 - learning_rate: 1.0000e-04
# Epoch 50/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 120us/step - accuracy: 0.8750 - loss: 0.3556 - val_accuracy: 0.9677 - val_loss: 0.0848 - learning_rate: 1.0000e-04
# Epoch 51/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 92ms/step - accuracy: 0.8830 - loss: 0.3331 - val_accuracy: 0.8281 - val_loss: 0.5038 - learning_rate: 1.0000e-04
# Epoch 52/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 107us/step - accuracy: 0.7500 - loss: 0.7965 - val_accuracy: 1.0000 - val_loss: 0.0547 - learning_rate: 1.0000e-04
# Epoch 53/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 98ms/step - accuracy: 0.8834 - loss: 0.3253 - val_accuracy: 0.8023 - val_loss: 0.5904 - learning_rate: 1.0000e-04
# Epoch 54/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 125us/step - accuracy: 0.8125 - loss: 0.4907 - val_accuracy: 0.9355 - val_loss: 0.0937 - learning_rate: 1.0000e-04
# Epoch 55/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 94ms/step - accuracy: 0.8837 - loss: 0.3400 - val_accuracy: 0.8141 - val_loss: 0.5825 - learning_rate: 1.0000e-04
# Epoch 56/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 125us/step - accuracy: 0.8750 - loss: 0.3633 - val_accuracy: 1.0000 - val_loss: 0.0781 - learning_rate: 1.0000e-04
# Epoch 57/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.8740 - loss: 0.3520 - val_accuracy: 0.8602 - val_loss: 0.4149 - learning_rate: 1.0000e-04
# Epoch 58/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9062 - loss: 0.2153 - val_accuracy: 1.0000 - val_loss: 0.0250 - learning_rate: 1.0000e-04
# Epoch 59/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 93ms/step - accuracy: 0.8973 - loss: 0.2963 - val_accuracy: 0.8617 - val_loss: 0.4324 - learning_rate: 1.0000e-04
# Epoch 60/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 106us/step - accuracy: 0.9062 - loss: 0.3882 - val_accuracy: 1.0000 - val_loss: 0.0253 - learning_rate: 1.0000e-04
# Epoch 61/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 93ms/step - accuracy: 0.8835 - loss: 0.3327 - val_accuracy: 0.8344 - val_loss: 0.4939 - learning_rate: 1.0000e-04
# Epoch 62/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 0.9375 - loss: 0.1830 - val_accuracy: 1.0000 - val_loss: 0.0417 - learning_rate: 1.0000e-04
# Epoch 63/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 100ms/step - accuracy: 0.8986 - loss: 0.2930 - val_accuracy: 0.7672 - val_loss: 0.7318 - learning_rate: 1.0000e-04
# Epoch 64/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 110us/step - accuracy: 0.8438 - loss: 0.4984 - val_accuracy: 0.9677 - val_loss: 0.1247 - learning_rate: 1.0000e-04
# Epoch 65/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 93ms/step - accuracy: 0.8905 - loss: 0.3039 - val_accuracy: 0.7922 - val_loss: 0.6493 - learning_rate: 1.0000e-04
# Epoch 66/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 115us/step - accuracy: 0.9375 - loss: 0.1506 - val_accuracy: 1.0000 - val_loss: 0.0547 - learning_rate: 1.0000e-04
# Epoch 67/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 99ms/step - accuracy: 0.8931 - loss: 0.2993 - val_accuracy: 0.8469 - val_loss: 0.4748 - learning_rate: 1.0000e-04
# Epoch 68/100
#   1/178 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9375 - loss: 0.1524
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9375 - loss: 0.1524 - val_accuracy: 1.0000 - val_loss: 0.0284 - learning_rate: 1.0000e-04
# Epoch 69/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 93ms/step - accuracy: 0.8942 - loss: 0.2967 - val_accuracy: 0.8344 - val_loss: 0.5249 - learning_rate: 1.0000e-05
# Epoch 70/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 133us/step - accuracy: 0.8438 - loss: 0.3520 - val_accuracy: 1.0000 - val_loss: 0.0207 - learning_rate: 1.0000e-05
# Epoch 71/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 99ms/step - accuracy: 0.8940 - loss: 0.2796 - val_accuracy: 0.8516 - val_loss: 0.4722 - learning_rate: 1.0000e-05
# Epoch 72/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8438 - loss: 0.5051 - val_accuracy: 1.0000 - val_loss: 0.0161 - learning_rate: 1.0000e-05
# Epoch 73/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 93ms/step - accuracy: 0.9012 - loss: 0.2925 - val_accuracy: 0.8453 - val_loss: 0.4894 - learning_rate: 1.0000e-05
# Epoch 74/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 122us/step - accuracy: 0.9375 - loss: 0.1678 - val_accuracy: 1.0000 - val_loss: 0.0180 - learning_rate: 1.0000e-05
# Epoch 75/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 93ms/step - accuracy: 0.8956 - loss: 0.2947 - val_accuracy: 0.8359 - val_loss: 0.5289 - learning_rate: 1.0000e-05
# Epoch 76/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 117us/step - accuracy: 0.9062 - loss: 0.2471 - val_accuracy: 1.0000 - val_loss: 0.0202 - learning_rate: 1.0000e-05
# Epoch 77/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 97ms/step - accuracy: 0.8996 - loss: 0.2756 - val_accuracy: 0.8469 - val_loss: 0.4824 - learning_rate: 1.0000e-05
# Epoch 78/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 127us/step - accuracy: 0.7812 - loss: 0.4503 - val_accuracy: 1.0000 - val_loss: 0.0183 - learning_rate: 1.0000e-05
# Epoch 79/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 19s 92ms/step - accuracy: 0.9035 - loss: 0.2674 - val_accuracy: 0.8406 - val_loss: 0.4941 - learning_rate: 1.0000e-05
# Epoch 80/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 127us/step - accuracy: 0.7812 - loss: 0.4945 - val_accuracy: 1.0000 - val_loss: 0.0197 - learning_rate: 1.0000e-05
# Epoch 81/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 21s 94ms/step - accuracy: 0.9038 - loss: 0.2825 - val_accuracy: 0.8469 - val_loss: 0.4788 - learning_rate: 1.0000e-05
# Epoch 82/100
#   1/178 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.8750 - loss: 0.2780
# Epoch 82: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 153us/step - accuracy: 0.8750 - loss: 0.2780 - val_accuracy: 1.0000 - val_loss: 0.0160 - learning_rate: 1.0000e-05
# Epoch 83/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 94ms/step - accuracy: 0.8937 - loss: 0.2932 - val_accuracy: 0.8414 - val_loss: 0.5007 - learning_rate: 1.0000e-06
# Epoch 84/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 125us/step - accuracy: 0.8438 - loss: 0.2896 - val_accuracy: 1.0000 - val_loss: 0.0180 - learning_rate: 1.0000e-06
# Epoch 85/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 93ms/step - accuracy: 0.8954 - loss: 0.2904 - val_accuracy: 0.8398 - val_loss: 0.5030 - learning_rate: 1.0000e-06
# Epoch 86/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 122us/step - accuracy: 0.9688 - loss: 0.1847 - val_accuracy: 1.0000 - val_loss: 0.0185 - learning_rate: 1.0000e-06
# Epoch 87/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 93ms/step - accuracy: 0.8994 - loss: 0.2994 - val_accuracy: 0.8422 - val_loss: 0.4963 - learning_rate: 1.0000e-06
# Epoch 88/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - accuracy: 0.8125 - loss: 0.6217 - val_accuracy: 1.0000 - val_loss: 0.0173 - learning_rate: 1.0000e-06
# Epoch 89/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 92ms/step - accuracy: 0.9018 - loss: 0.2837 - val_accuracy: 0.8414 - val_loss: 0.4963 - learning_rate: 1.0000e-06
# Epoch 90/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.9062 - loss: 0.2066 - val_accuracy: 1.0000 - val_loss: 0.0175 - learning_rate: 1.0000e-06
# Epoch 91/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 17s 93ms/step - accuracy: 0.9028 - loss: 0.2761 - val_accuracy: 0.8391 - val_loss: 0.5069 - learning_rate: 1.0000e-06
# Epoch 92/100
#   1/178 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9688 - loss: 0.2169
# Epoch 92: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 145us/step - accuracy: 0.9688 - loss: 0.2169 - val_accuracy: 1.0000 - val_loss: 0.0188 - learning_rate: 1.0000e-06
# Epoch 93/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 99ms/step - accuracy: 0.9034 - loss: 0.2794 - val_accuracy: 0.8383 - val_loss: 0.5100 - learning_rate: 1.0000e-07
# Epoch 94/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 156us/step - accuracy: 0.9062 - loss: 0.3469 - val_accuracy: 1.0000 - val_loss: 0.0186 - learning_rate: 1.0000e-07
# Epoch 95/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 99ms/step - accuracy: 0.8958 - loss: 0.2972 - val_accuracy: 0.8406 - val_loss: 0.4998 - learning_rate: 1.0000e-07
# Epoch 96/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 132us/step - accuracy: 0.8438 - loss: 0.3684 - val_accuracy: 1.0000 - val_loss: 0.0185 - learning_rate: 1.0000e-07
# Epoch 97/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 20s 99ms/step - accuracy: 0.9019 - loss: 0.2797 - val_accuracy: 0.8406 - val_loss: 0.4954 - learning_rate: 1.0000e-07
# Epoch 98/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9062 - loss: 0.3240 - val_accuracy: 1.0000 - val_loss: 0.0176 - learning_rate: 1.0000e-07
# Epoch 99/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.8873 - loss: 0.3069 - val_accuracy: 0.8406 - val_loss: 0.4994 - learning_rate: 1.0000e-07
# Epoch 100/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 124us/step - accuracy: 0.9375 - loss: 0.3161 - val_accuracy: 1.0000 - val_loss: 0.0180 - learning_rate: 1.0000e-07

# %% [markdown]
# <br>

# %%
train_score = model_all.evaluate(train_generator)
test_score = model_all.evaluate(test_generator)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 89ms/step - accuracy: 0.9156 - loss: 0.2372
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7790 - loss: 0.6956
# Train Loss:  0.23107923567295074
# Train Accuracy:  0.9215686321258545
# --------------------
# --------------------
# Test Loss:  0.48838698863983154
# Test Accuracy:  0.8443936109542847

# %%
plt.plot(history_all.history['accuracy'], label='Training Accuracy')
plt.plot(history_all.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(history_all.history['loss'], label='Training Loss')
plt.plot(history_all.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# It is clear that the final model does extremely well to relatively improve the "oscillation" problem that we have consistently faced throughout, by evidence of the training and validation accuracies and losses noow oscillating with a smaller range. The overall performance of the model although not as good as some of the trained models here for instance the [LR scheduler](#scrollTo=Kg2qgirW15y2) or even the [base model](#scrollTo=mj1aL4LyWNlZ), still can be considered as acceptable and performs well on unseen data (i.e. training data). Further analysis by looking at various other paramters that can be tuned can enhance model performance and generalisation but due to computational resitrictions, we will stop here.

# %% [markdown]
# # 4. The concept of "Best Model"
# While all models considered here have their own benefits, for instance the early stopping model providing lesser number of epochs for faster training, the model with xavier initialisation trying to solve the vanishing gradient problem, regularisation model preventing overfitting, and the model with all hyperparameters tuned showing multiple benefits, it is clear by the training accuracy of 0.9366 that the reduced LR model has generalised better on this particular test data. While we cannot conclusively tag it to be the "best" model in a more general sense, for our current problem, we shall consider the [final model](#scrollTo=jmC4OTcAIKtd) which we have developed using all the possible parameter tunings.
# Hence, while the Reduce LR model considering ReduceLROnPlateau scheduler offers a good balance between model performance and complexity, the most optimal model that takes care of overfitting, improves convergence speed, and overall helps in understanding the data on a deeper sacale is the [final model](#scrollTo=jmC4OTcAIKtd), making it more suitable than the other models that have been trained.

# %% [markdown]
# <br>

# %% [markdown]
# # 4.1 Upscaling using the final model
# With the information about the best model in hand, we now aim to upscale our research from the perspective of smaller size images, originally chosen as 64x64, to a 128x128 size. This will not only inform us if the model we have chosen makes sense in aa upscaled version of our original findings, but also if the current environment we have chosen with the computational limitations will be able to handle the greater load of compiling a large set of heavy images.

# %% [markdown]
# <br>

# %%
train_dir = Path('cleaned/Training')
test_dir = Path('cleaned/Testing')

LABELS = ['pituitary', 'notumor', 'meningioma', 'glioma']


IMG_SIZE = 128  # Upscaled
BATCH_SIZE = 32


train_datagen = ImageDataGenerator(
    rescale=1.0/255.0,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    brightness_range=(0.5, 1.5),
    channel_shift_range=20.0
)

test_datagen = ImageDataGenerator(rescale=1.0/255.0)


print('Training Data: ')

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE), # Image size is now 128x128
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)


print('Testing Data: ')
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),  # Image size is now 128x128
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Training Data:
# Found 5712 images belonging to 4 classes.
# Testing Data:
# Found 1311 images belonging to 4 classes.

# %% [markdown]
# <br>

# %%
from tensorflow.keras.initializers import GlorotUniform
model_scaled = Sequential([
    Conv2D(64, kernel_size=(3, 3), activation='tanh', input_shape=(128, 128, 3),kernel_initializer=GlorotUniform()), #input_shape changed from
    # to (128,128,3) given image size is scaled.
    MaxPooling2D((2, 2)),
    BatchNormalization(),

    Conv2D(128, kernel_size=(3, 3), activation='tanh',kernel_initializer=GlorotUniform()),
    MaxPooling2D((2, 2)),
    BatchNormalization(),

    Conv2D(256, kernel_size=(3, 3), activation='tanh',kernel_initializer=GlorotUniform()),
    MaxPooling2D((2, 2)),
    BatchNormalization(),

    Conv2D(512, kernel_size=(3, 3), activation='tanh',kernel_initializer=GlorotUniform()),
    MaxPooling2D((2, 2)),
    BatchNormalization(),


    Flatten(),
    Dense(512, activation='tanh', kernel_initializer=GlorotUniform()),
    Dropout(0.5),
    Dense(128, activation='tanh', kernel_initializer=GlorotUniform()),
    Dropout(0.5),

    Dense(4, activation='softmax')  # Output layer for 4 classes
])

model_scaled.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=10,
    verbose=1,
    min_delta=0.0001,
    cooldown=0,
    min_lr=0,
)

# %%
history_scaled = model_scaled.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=100,
    validation_data=test_generator,
    validation_steps=test_generator.samples // BATCH_SIZE
    ,callbacks=[reduce_lr])
# Out:
# Epoch 1/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 54s 265ms/step - accuracy: 0.2782 - loss: 1.9476 - val_accuracy: 0.3187 - val_loss: 1.4199 - learning_rate: 0.0010
# Epoch 2/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.1562 - loss: 1.7447 - val_accuracy: 0.0000e+00 - val_loss: 1.8386 - learning_rate: 0.0010
# Epoch 3/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 66s 206ms/step - accuracy: 0.2866 - loss: 1.6372 - val_accuracy: 0.3156 - val_loss: 1.3721 - learning_rate: 0.0010
# Epoch 4/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 141us/step - accuracy: 0.1875 - loss: 1.5466 - val_accuracy: 0.0323 - val_loss: 1.9056 - learning_rate: 0.0010
# Epoch 5/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 205ms/step - accuracy: 0.3029 - loss: 1.5032 - val_accuracy: 0.4156 - val_loss: 1.2798 - learning_rate: 0.0010
# Epoch 6/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2812 - loss: 1.4500 - val_accuracy: 0.1290 - val_loss: 1.4433 - learning_rate: 0.0010
# Epoch 7/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 41s 208ms/step - accuracy: 0.2956 - loss: 1.4155 - val_accuracy: 0.3266 - val_loss: 1.3826 - learning_rate: 0.0010
# Epoch 8/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 139us/step - accuracy: 0.4062 - loss: 1.3517 - val_accuracy: 0.0000e+00 - val_loss: 1.4888 - learning_rate: 0.0010
# Epoch 9/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 41s 208ms/step - accuracy: 0.3165 - loss: 1.3856 - val_accuracy: 0.3602 - val_loss: 1.3424 - learning_rate: 0.0010
# Epoch 10/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2812 - loss: 1.3942 - val_accuracy: 0.0000e+00 - val_loss: 1.4855 - learning_rate: 0.0010
# Epoch 11/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 38s 210ms/step - accuracy: 0.3364 - loss: 1.3554 - val_accuracy: 0.3117 - val_loss: 1.4688 - learning_rate: 0.0010
# Epoch 12/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 138us/step - accuracy: 0.4375 - loss: 1.2935 - val_accuracy: 0.0645 - val_loss: 1.6986 - learning_rate: 0.0010
# Epoch 13/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 41s 210ms/step - accuracy: 0.3646 - loss: 1.3381 - val_accuracy: 0.3187 - val_loss: 1.6687 - learning_rate: 0.0010
# Epoch 14/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 148us/step - accuracy: 0.3438 - loss: 1.2399 - val_accuracy: 0.0000e+00 - val_loss: 1.8007 - learning_rate: 0.0010
# Epoch 15/100
# 177/178 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.3680 - loss: 1.3196
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.3678 - loss: 1.3197 - val_accuracy: 0.3164 - val_loss: 1.6287 - learning_rate: 0.0010
# Epoch 16/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 147us/step - accuracy: 0.2500 - loss: 1.3565 - val_accuracy: 0.0000e+00 - val_loss: 1.5779 - learning_rate: 1.0000e-04
# Epoch 17/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 38s 208ms/step - accuracy: 0.3775 - loss: 1.3124 - val_accuracy: 0.3328 - val_loss: 1.4679 - learning_rate: 1.0000e-04
# Epoch 18/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5000 - loss: 1.2007 - val_accuracy: 0.0323 - val_loss: 1.6390 - learning_rate: 1.0000e-04
# Epoch 19/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 211ms/step - accuracy: 0.4031 - loss: 1.2764 - val_accuracy: 0.3242 - val_loss: 1.7436 - learning_rate: 1.0000e-04
# Epoch 20/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 141us/step - accuracy: 0.4375 - loss: 1.1740 - val_accuracy: 0.0000e+00 - val_loss: 1.8585 - learning_rate: 1.0000e-04
# Epoch 21/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 202ms/step - accuracy: 0.4084 - loss: 1.2581 - val_accuracy: 0.3539 - val_loss: 1.4321 - learning_rate: 1.0000e-04
# Epoch 22/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 152us/step - accuracy: 0.2812 - loss: 1.2875 - val_accuracy: 0.0000e+00 - val_loss: 1.7907 - learning_rate: 1.0000e-04
# Epoch 23/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 41s 208ms/step - accuracy: 0.4229 - loss: 1.2301 - val_accuracy: 0.4367 - val_loss: 1.2473 - learning_rate: 1.0000e-04
# Epoch 24/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4688 - loss: 1.1820 - val_accuracy: 0.0000e+00 - val_loss: 1.5887 - learning_rate: 1.0000e-04
# Epoch 25/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 208ms/step - accuracy: 0.4436 - loss: 1.2105 - val_accuracy: 0.3531 - val_loss: 1.4269 - learning_rate: 1.0000e-04
# Epoch 26/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 150us/step - accuracy: 0.4062 - loss: 1.2098 - val_accuracy: 0.0323 - val_loss: 1.4637 - learning_rate: 1.0000e-04
# Epoch 27/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 38s 207ms/step - accuracy: 0.4479 - loss: 1.1901 - val_accuracy: 0.3539 - val_loss: 1.4125 - learning_rate: 1.0000e-04
# Epoch 28/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6562 - loss: 0.9814 - val_accuracy: 0.0323 - val_loss: 1.4280 - learning_rate: 1.0000e-04
# Epoch 29/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 41s 214ms/step - accuracy: 0.4672 - loss: 1.1702 - val_accuracy: 0.4281 - val_loss: 1.2221 - learning_rate: 1.0000e-04
# Epoch 30/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 152us/step - accuracy: 0.5625 - loss: 0.9536 - val_accuracy: 0.0323 - val_loss: 1.3297 - learning_rate: 1.0000e-04
# Epoch 31/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 208ms/step - accuracy: 0.4539 - loss: 1.1616 - val_accuracy: 0.5211 - val_loss: 1.0718 - learning_rate: 1.0000e-04
# Epoch 32/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 143us/step - accuracy: 0.3438 - loss: 1.2892 - val_accuracy: 0.1935 - val_loss: 1.2506 - learning_rate: 1.0000e-04
# Epoch 33/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 41s 209ms/step - accuracy: 0.4662 - loss: 1.1444 - val_accuracy: 0.5406 - val_loss: 1.0728 - learning_rate: 1.0000e-04
# Epoch 34/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 152us/step - accuracy: 0.6562 - loss: 0.9791 - val_accuracy: 0.3548 - val_loss: 1.2842 - learning_rate: 1.0000e-04
# Epoch 35/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 38s 209ms/step - accuracy: 0.4694 - loss: 1.1229 - val_accuracy: 0.5305 - val_loss: 1.0869 - learning_rate: 1.0000e-04
# Epoch 36/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 142us/step - accuracy: 0.6250 - loss: 0.9695 - val_accuracy: 0.2903 - val_loss: 1.1229 - learning_rate: 1.0000e-04
# Epoch 37/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 41s 205ms/step - accuracy: 0.4817 - loss: 1.1165 - val_accuracy: 0.3555 - val_loss: 1.5388 - learning_rate: 1.0000e-04
# Epoch 38/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4062 - loss: 1.1546 - val_accuracy: 0.0968 - val_loss: 1.1336 - learning_rate: 1.0000e-04
# Epoch 39/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 39s 207ms/step - accuracy: 0.4902 - loss: 1.0672 - val_accuracy: 0.3992 - val_loss: 1.3916 - learning_rate: 1.0000e-04
# Epoch 40/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 219us/step - accuracy: 0.5938 - loss: 1.0541 - val_accuracy: 0.2581 - val_loss: 1.0617 - learning_rate: 1.0000e-04
# Epoch 41/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 38s 206ms/step - accuracy: 0.4996 - loss: 1.0701 - val_accuracy: 0.5266 - val_loss: 1.0989 - learning_rate: 1.0000e-04
# Epoch 42/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5000 - loss: 0.9983 - val_accuracy: 0.9677 - val_loss: 0.9071 - learning_rate: 1.0000e-04
# Epoch 43/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 216ms/step - accuracy: 0.5060 - loss: 1.0549 - val_accuracy: 0.5383 - val_loss: 1.0424 - learning_rate: 1.0000e-04
# Epoch 44/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4375 - loss: 1.2161 - val_accuracy: 0.9355 - val_loss: 0.8715 - learning_rate: 1.0000e-04
# Epoch 45/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 39s 208ms/step - accuracy: 0.5148 - loss: 1.0452 - val_accuracy: 0.5828 - val_loss: 1.0062 - learning_rate: 1.0000e-04
# Epoch 46/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5938 - loss: 1.0003 - val_accuracy: 0.8387 - val_loss: 0.8932 - learning_rate: 1.0000e-04
# Epoch 47/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 39s 210ms/step - accuracy: 0.5122 - loss: 1.0432 - val_accuracy: 0.5508 - val_loss: 0.9716 - learning_rate: 1.0000e-04
# Epoch 48/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5312 - loss: 1.0960 - val_accuracy: 0.9355 - val_loss: 0.7895 - learning_rate: 1.0000e-04
# Epoch 49/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 41s 212ms/step - accuracy: 0.5419 - loss: 0.9829 - val_accuracy: 0.5227 - val_loss: 0.9811 - learning_rate: 1.0000e-04
# Epoch 50/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 175us/step - accuracy: 0.6250 - loss: 0.8403 - val_accuracy: 0.9677 - val_loss: 0.6837 - learning_rate: 1.0000e-04
# Epoch 51/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 41s 211ms/step - accuracy: 0.5537 - loss: 0.9953 - val_accuracy: 0.5156 - val_loss: 0.9863 - learning_rate: 1.0000e-04
# Epoch 52/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 145us/step - accuracy: 0.5938 - loss: 0.9716 - val_accuracy: 0.9677 - val_loss: 0.5513 - learning_rate: 1.0000e-04
# Epoch 53/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 39s 211ms/step - accuracy: 0.5655 - loss: 0.9817 - val_accuracy: 0.4125 - val_loss: 1.3059 - learning_rate: 1.0000e-04
# Epoch 54/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4062 - loss: 1.1488 - val_accuracy: 1.0000 - val_loss: 0.3476 - learning_rate: 1.0000e-04
# Epoch 55/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 39s 212ms/step - accuracy: 0.5786 - loss: 0.9553 - val_accuracy: 0.4586 - val_loss: 1.2139 - learning_rate: 1.0000e-04
# Epoch 56/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 145us/step - accuracy: 0.4688 - loss: 0.9472 - val_accuracy: 1.0000 - val_loss: 0.3539 - learning_rate: 1.0000e-04
# Epoch 57/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 217ms/step - accuracy: 0.6013 - loss: 0.9350 - val_accuracy: 0.4773 - val_loss: 1.2057 - learning_rate: 1.0000e-04
# Epoch 58/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 147us/step - accuracy: 0.6562 - loss: 0.8331 - val_accuracy: 0.9677 - val_loss: 0.3685 - learning_rate: 1.0000e-04
# Epoch 59/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 39s 212ms/step - accuracy: 0.6138 - loss: 0.8901 - val_accuracy: 0.5156 - val_loss: 1.2445 - learning_rate: 1.0000e-04
# Epoch 60/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 143us/step - accuracy: 0.7188 - loss: 0.7694 - val_accuracy: 1.0000 - val_loss: 0.2160 - learning_rate: 1.0000e-04
# Epoch 61/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 220ms/step - accuracy: 0.6525 - loss: 0.8551 - val_accuracy: 0.5234 - val_loss: 1.2314 - learning_rate: 1.0000e-04
# Epoch 62/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6250 - loss: 0.9091 - val_accuracy: 0.9677 - val_loss: 0.2192 - learning_rate: 1.0000e-04
# Epoch 63/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 79s 211ms/step - accuracy: 0.6638 - loss: 0.8344 - val_accuracy: 0.6031 - val_loss: 1.0168 - learning_rate: 1.0000e-04
# Epoch 64/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7812 - loss: 0.7404 - val_accuracy: 1.0000 - val_loss: 0.2556 - learning_rate: 1.0000e-04
# Epoch 65/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 38s 205ms/step - accuracy: 0.6717 - loss: 0.8252 - val_accuracy: 0.6352 - val_loss: 0.9618 - learning_rate: 1.0000e-04
# Epoch 66/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5625 - loss: 0.9660 - val_accuracy: 0.9677 - val_loss: 0.2475 - learning_rate: 1.0000e-04
# Epoch 67/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 38s 207ms/step - accuracy: 0.6643 - loss: 0.8356 - val_accuracy: 0.5930 - val_loss: 1.0861 - learning_rate: 1.0000e-04
# Epoch 68/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6875 - loss: 0.7151 - val_accuracy: 0.9677 - val_loss: 0.2498 - learning_rate: 1.0000e-04
# Epoch 69/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 42s 216ms/step - accuracy: 0.6938 - loss: 0.7765 - val_accuracy: 0.6531 - val_loss: 0.9168 - learning_rate: 1.0000e-04
# Epoch 70/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 155us/step - accuracy: 0.7500 - loss: 0.7007 - val_accuracy: 0.9677 - val_loss: 0.2132 - learning_rate: 1.0000e-04
# Epoch 71/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 209ms/step - accuracy: 0.7037 - loss: 0.7522 - val_accuracy: 0.6484 - val_loss: 0.9323 - learning_rate: 1.0000e-04
# Epoch 72/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 157us/step - accuracy: 0.6875 - loss: 0.6742 - val_accuracy: 1.0000 - val_loss: 0.1791 - learning_rate: 1.0000e-04
# Epoch 73/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 39s 212ms/step - accuracy: 0.7237 - loss: 0.7259 - val_accuracy: 0.6438 - val_loss: 0.9419 - learning_rate: 1.0000e-04
# Epoch 74/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 150us/step - accuracy: 0.7188 - loss: 0.6390 - val_accuracy: 1.0000 - val_loss: 0.1544 - learning_rate: 1.0000e-04
# Epoch 75/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 41s 210ms/step - accuracy: 0.7261 - loss: 0.7126 - val_accuracy: 0.6617 - val_loss: 0.8821 - learning_rate: 1.0000e-04
# Epoch 76/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 143us/step - accuracy: 0.6250 - loss: 1.0263 - val_accuracy: 0.9677 - val_loss: 0.2044 - learning_rate: 1.0000e-04
# Epoch 77/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 38s 209ms/step - accuracy: 0.7235 - loss: 0.7244 - val_accuracy: 0.5852 - val_loss: 1.2372 - learning_rate: 1.0000e-04
# Epoch 78/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 171us/step - accuracy: 0.6875 - loss: 0.7398 - val_accuracy: 1.0000 - val_loss: 0.1196 - learning_rate: 1.0000e-04
# Epoch 79/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 39s 213ms/step - accuracy: 0.7245 - loss: 0.6937 - val_accuracy: 0.6281 - val_loss: 1.1226 - learning_rate: 1.0000e-04
# Epoch 80/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6562 - loss: 0.7931 - val_accuracy: 1.0000 - val_loss: 0.1346 - learning_rate: 1.0000e-04
# Epoch 81/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 39s 209ms/step - accuracy: 0.7472 - loss: 0.6630 - val_accuracy: 0.6906 - val_loss: 0.9016 - learning_rate: 1.0000e-04
# Epoch 82/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 154us/step - accuracy: 0.7188 - loss: 0.6854 - val_accuracy: 0.9677 - val_loss: 0.2107 - learning_rate: 1.0000e-04
# Epoch 83/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 42s 215ms/step - accuracy: 0.7520 - loss: 0.6588 - val_accuracy: 0.6203 - val_loss: 1.1224 - learning_rate: 1.0000e-04
# Epoch 84/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 141us/step - accuracy: 0.7812 - loss: 0.6253 - val_accuracy: 1.0000 - val_loss: 0.0967 - learning_rate: 1.0000e-04
# Epoch 85/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 209ms/step - accuracy: 0.7387 - loss: 0.6741 - val_accuracy: 0.6922 - val_loss: 0.9108 - learning_rate: 1.0000e-04
# Epoch 86/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 154us/step - accuracy: 0.6562 - loss: 0.9734 - val_accuracy: 1.0000 - val_loss: 0.1275 - learning_rate: 1.0000e-04
# Epoch 87/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 41s 226ms/step - accuracy: 0.7493 - loss: 0.6659 - val_accuracy: 0.6516 - val_loss: 1.1010 - learning_rate: 1.0000e-04
# Epoch 88/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 151us/step - accuracy: 0.7500 - loss: 0.5295 - val_accuracy: 0.8387 - val_loss: 0.3141 - learning_rate: 1.0000e-04
# Epoch 89/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 81s 220ms/step - accuracy: 0.7643 - loss: 0.6320 - val_accuracy: 0.6258 - val_loss: 1.0493 - learning_rate: 1.0000e-04
# Epoch 90/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7188 - loss: 0.8506 - val_accuracy: 1.0000 - val_loss: 0.0649 - learning_rate: 1.0000e-04
# Epoch 91/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 39s 212ms/step - accuracy: 0.7437 - loss: 0.6677 - val_accuracy: 0.6914 - val_loss: 0.9947 - learning_rate: 1.0000e-04
# Epoch 92/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 154us/step - accuracy: 0.7812 - loss: 0.5669 - val_accuracy: 1.0000 - val_loss: 0.0960 - learning_rate: 1.0000e-04
# Epoch 93/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 38s 209ms/step - accuracy: 0.7762 - loss: 0.6200 - val_accuracy: 0.6898 - val_loss: 0.9120 - learning_rate: 1.0000e-04
# Epoch 94/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 152us/step - accuracy: 0.8750 - loss: 0.4420 - val_accuracy: 1.0000 - val_loss: 0.0896 - learning_rate: 1.0000e-04
# Epoch 95/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 42s 217ms/step - accuracy: 0.7832 - loss: 0.5965 - val_accuracy: 0.6891 - val_loss: 1.0498 - learning_rate: 1.0000e-04
# Epoch 96/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.5828 - val_accuracy: 0.9032 - val_loss: 0.3000 - learning_rate: 1.0000e-04
# Epoch 97/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 38s 205ms/step - accuracy: 0.7665 - loss: 0.6176 - val_accuracy: 0.7008 - val_loss: 0.8843 - learning_rate: 1.0000e-04
# Epoch 98/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 150us/step - accuracy: 0.7500 - loss: 0.7005 - val_accuracy: 1.0000 - val_loss: 0.0716 - learning_rate: 1.0000e-04
# Epoch 99/100
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 39s 206ms/step - accuracy: 0.7678 - loss: 0.6133 - val_accuracy: 0.6773 - val_loss: 0.9369 - learning_rate: 1.0000e-04
# Epoch 100/100
#   1/178 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - accuracy: 0.7188 - loss: 0.7098
# Epoch 100: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7188 - loss: 0.7098 - val_accuracy: 1.0000 - val_loss: 0.1085 - learning_rate: 1.0000e-04

# %%
train_score = model_scaled.evaluate(train_generator)
test_score = model_scaled.evaluate(test_generator)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 36s 199ms/step - accuracy: 0.7540 - loss: 0.6518
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.6495 - loss: 0.9280
# Train Loss:  0.6672083139419556
# Train Accuracy:  0.7477241158485413
# --------------------
# --------------------
# Test Loss:  0.7545393109321594
# Test Accuracy:  0.711670458316803

# %%
plt.plot(history_scaled.history['accuracy'], label='Training Accuracy')
plt.plot(history_scaled.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(history_scaled.history['loss'], label='Training Loss')
plt.plot(history_scaled.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# On using the final model which we termed as the better model out of all, we observe a decrease in model performance when the image size is upscaled to 128. There are multiple reasons why this could occur. As image size incerases, the complexity of the image increases, and since we have defined a pretty simple architecture, it may imply worsened performance. This means it may require more number of layers, paramaters and a complex architectural structure to effectively learn the new features.
# While the overall accuracy may have one positive out of this is that the training and testing accuracy are not that far apart, which can imply that the model has generalised well on unseen data. But, we have to keep in mind that this could be a sign of underfitting as well, since our model is not complex.

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# # 5. Evaluating on Test Data
# All the models are now evaluated on the test data, in specific I have taken random images from the __Testing__ subfolder and used the trained models to predict whether the image is 1 of the 4 classifications of brain tumors. There is no perfect way to choose the best model, but I have simply portrayed the comparisons of the model's ability to predict on unseen data. In fact multiple images can be chosen to test prediction.

# %% [markdown]
# # 5.1 Base Model

# %%
model_base=keras.models.load_model('model_base.keras')

# %%
from tensorflow import keras

from tensorflow.keras.preprocessing import image

def predict_image(model, img_path, target_size=(64, 64)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0  # normalize as trained

    prediction = model_base.predict(img_array)
    class_index = np.argmax(prediction, axis=1)[0]
    class_label = list(train_generator.class_indices.keys())[class_index]
    prediction_score = prediction[0][class_index]

    return class_label, prediction_score

# Predict a new image
img_path = keras.utils.load_img('/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/pituitary/Te-pi_0292.jpg')
plt.imshow(img_path)
img = '/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/pituitary/Te-pi_0292.jpg'
predicted_label, prediction_score = predict_image(model_base, img)
print(f"The predicted label is: {predicted_label}")
print(f"Prediction score for {predicted_label}: {prediction_score:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# The predicted label is: pituitary
# Prediction score for pituitary: 0.9950

# %% [markdown]
# <br>

# %% [markdown]
# # 5.2 Model with Regularisation

# %%
from tensorflow import keras

from tensorflow.keras.preprocessing import image

def predict_image(model, img_path, target_size=(64, 64)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0  # normalize as trained

    prediction = model_reg.predict(img_array)
    class_index = np.argmax(prediction, axis=1)[0]
    class_label = list(train_generator.class_indices.keys())[class_index]
    prediction_score = prediction[0][class_index]

    return class_label, prediction_score

# Predict a new image
img_path = keras.utils.load_img('/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/glioma/Te-gl_0293.jpg')
plt.imshow(img_path)
img = '/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/glioma/Te-gl_0293.jpg'
predicted_label, prediction_score = predict_image(model_reg, img)
print(f"The predicted label is: {predicted_label}")
print(f"Prediction score for {predicted_label}: {prediction_score:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# The predicted label is: glioma
# Prediction score for glioma: 0.9128

# %% [markdown]
# <br>

# %% [markdown]
# # 5.3 Model with Early Stopping

# %%
from tensorflow import keras

from tensorflow.keras.preprocessing import image

def predict_image(model, img_path, target_size=(64, 64)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0  # normalize as trained

    prediction = model_early.predict(img_array)
    class_index = np.argmax(prediction, axis=1)[0]
    class_label = list(train_generator.class_indices.keys())[class_index]
    prediction_score = prediction[0][class_index]

    return class_label, prediction_score

# Predict a new image
img_path = keras.utils.load_img('/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/notumor/Te-no_0185.jpg')
plt.imshow(img_path)
img = '/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/notumor/Te-no_0185.jpg'
predicted_label, prediction_score = predict_image(model_early, img)
print(f"The predicted label is: {predicted_label}")
print(f"Prediction score for {predicted_label}: {prediction_score:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step
# The predicted label is: notumor
# Prediction score for notumor: 0.9721

# %% [markdown]
# <br>

# %% [markdown]
# # 5.4 Model with Reduced Learning Rate

# %%
from tensorflow import keras

from tensorflow.keras.preprocessing import image

def predict_image(model, img_path, target_size=(64, 64)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0  # normalize as trained

    prediction = model_reduce_lr.predict(img_array)
    class_index = np.argmax(prediction, axis=1)[0]
    class_label = list(train_generator.class_indices.keys())[class_index]
    prediction_score = prediction[0][class_index]

    return class_label, prediction_score

# Predict a new image
img_path = keras.utils.load_img('/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/pituitary/Te-pi_0139.jpg')
plt.imshow(img_path)
img = '/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/pituitary/Te-pi_0139.jpg'
predicted_label, prediction_score = predict_image(model_reduce_lr, img)
print(f"The predicted label is: {predicted_label}")
print(f"Prediction score for {predicted_label}: {prediction_score:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# The predicted label is: pituitary
# Prediction score for pituitary: 0.9979

# %% [markdown]
# <br>

# %% [markdown]
# # 5.5 Model with Xavier Initialisation

# %%
from tensorflow import keras

from tensorflow.keras.preprocessing import image

def predict_image(model, img_path, target_size=(64, 64)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0  # normalize as trained

    prediction = model_xavier.predict(img_array)
    class_index = np.argmax(prediction, axis=1)[0]
    class_label = list(train_generator.class_indices.keys())[class_index]
    prediction_score = prediction[0][class_index]

    return class_label, prediction_score

# Predict a new image
img_path = keras.utils.load_img('/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/meningioma/Te-me_0034.jpg')
plt.imshow(img_path)
img = '/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/meningioma/Te-me_0034.jpg'
predicted_label, prediction_score = predict_image(model_xavier, img)
print(f"The predicted label is: {predicted_label}")
print(f"Prediction score for {predicted_label}: {prediction_score:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# The predicted label is: meningioma
# Prediction score for meningioma: 0.8125

# %% [markdown]
# <br>

# %% [markdown]
# # 5.6 Final Model

# %%
from tensorflow import keras

from tensorflow.keras.preprocessing import image

def predict_image(model, img_path, target_size=(64, 64)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0  # normalize as trained

    prediction = model_all.predict(img_array)
    class_index = np.argmax(prediction, axis=1)[0]
    class_label = list(train_generator.class_indices.keys())[class_index]
    prediction_score = prediction[0][class_index]

    return class_label, prediction_score

# Predict a new image
img_path = keras.utils.load_img('/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/pituitary/Te-pi_0295.jpg')
plt.imshow(img_path)
img = '/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/pituitary/Te-pi_0295.jpg'
predicted_label, prediction_score = predict_image(model_all, img)
print(f"The predicted label is: {predicted_label}")
print(f"Prediction score for {predicted_label}: {prediction_score:.4f}")
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e844a7d5630> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# The predicted label is: pituitary
# Prediction score for pituitary: 0.9907

# %% [markdown]
# <br>

# %% [markdown]
# # 5.7 Model for Scaled Image

# %%
from tensorflow import keras

from tensorflow.keras.preprocessing import image

def predict_image(model, img_path, target_size=(128, 128)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0  # normalize as trained

    prediction = model_scaled.predict(img_array)
    class_index = np.argmax(prediction, axis=1)[0]
    class_label = list(train_generator.class_indices.keys())[class_index]
    prediction_score = prediction[0][class_index]

    return class_label, prediction_score

# Predict a new image
img_path = keras.utils.load_img('/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/pituitary/Te-pi_0282.jpg')
plt.imshow(img_path)
img = '/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing/pituitary/Te-pi_0282.jpg'
predicted_label, prediction_score = predict_image(model_scaled, img)
print(f"The predicted label is: {predicted_label}")
print(f"Prediction score for {predicted_label}: {prediction_score:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# The predicted label is: pituitary
# Prediction score for pituitary: 0.9536

# %% [markdown]
# # 7. Conclusion
#
# On observing the various models i.e., base model, adding regularisation, early stopping, reduced learning rate scheduler and weight initialisation, it is observed that there are similar characteristics to most models, one being the representations of the training and validation accuracies and scores. On graphical visualisation, we can see an oscillatory behaviour which could be caused by multiple reasons. One could be due to the learning rate being 0.001, causing instability and large fluctuations, and it is observed in the graph for reduced learning rate, a more stable and less oscillatory trend is observed, especially with respect to the training accuracies and losses. Since I have not investiagted on the batch size, this could also be the reason as smaller batch sizes can introduce noise in gradient updates.
# <br>
# The other thing to observe is that on random selection of images from the testing folder, it is clear to see that all models perform well except maybe the model with regularisation. Now, since we have chosen the images at random, it could be that this model predicts other images well, but this cannot be guaranteed. In fact even for the "well-performing" models, prediction results as seen here is not conclusive proof that the model predicts every kind of image accurately. But, computationally this will be extremely tedious, and hence why it is not included.
# <br>
# There is obviously no "best" model that ever be made, but out of the sample of models we have created, it is obvious by the training and testing accuracy scores that the __Reduced Learning Rate Model__ is a viable option, but in terms of overall performance of the model considering the fact that multiple parameters have been used to improve convergence, attempt to mitigate the problem of overfitting and enhance training stability and performance, the final model is considered to be relatively better.
# <br>
# As a direct consequence of choosing the "best" model, the upscaled version of the images from 64x64 to 128x128 are subjected to prediction by training the final model on it and as observed, due to its simple architecture and inability to capture complex relationships between features of images, the accruacy scores drop by ~10% (we are interested in the model's generalisation on unseen data and hence consider the training accuracy). Better data augmentation, deeper understanding and investigation of parameter tuning, and a better computational environment can defintely result in a naunced understanding of model performance and subsequently help improve model performance. The scope of this project would be to next increase the amount of data by lets say x1000 and analyze changes to computational complexity, time and model creation and performance.
